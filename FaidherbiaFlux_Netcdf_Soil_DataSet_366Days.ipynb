# %% [markdown]
# # Traitement du dataset

# %%
import numpy as np
import pandas as pd

# %%
file_year='2020'
path = '/home/openopse/Documents/OPENOPSE/data/Olivier Roupsard/updated_new/netcdf/'

# %%
data= pd.read_csv("/home/openopse/Documents/OPENOPSE/data/Olivier Roupsard/updated_new/OpenOPSE_Roupsard/per Year/2020/OutdataFFlux_OpenOPSE_Soil_2020.csv")
data.head()
# Out:
#    Year    Date_fac  Hour_fac            DateSemih  Tsoil_0cm_FullSun  \
# 0  2020  2020-01-01  00:15:00  2020-01-01 00:15:00              24.72
# 1  2020  2020-01-01  00:45:00  2020-01-01 00:45:00              24.35
# 2  2020  2020-01-01  01:15:00  2020-01-01 01:15:00              24.16
# 3  2020  2020-01-01  01:45:00  2020-01-01 01:45:00              24.18
# 4  2020  2020-01-01  02:15:00  2020-01-01 02:15:00              24.03
#
#    IR100_LST_TallAnt_degC  IR120_LST_TallAnt_degC  \
# 0                   19.72                   20.90
# 1                   19.37                   20.60
# 2                   20.00                   21.32
# 3                   20.23                   21.53
# 4                   19.36                   20.55
#
#    TSoil_2cm_FullSun_Tall.Antenna_degC  TSoil_5cm_FullSun_Tall.Antenna_degC  \
# 0                                25.75                                26.95
# 1                                25.40                                26.64
# ...

# %%
data = data.fillna(float('nan'))

# %%
data.head()
# Out:
#    Year    Date_fac  Hour_fac            DateSemih  Tsoil_0cm_FullSun  \
# 0  2020  2020-01-01  00:15:00  2020-01-01 00:15:00              24.72
# 1  2020  2020-01-01  00:45:00  2020-01-01 00:45:00              24.35
# 2  2020  2020-01-01  01:15:00  2020-01-01 01:15:00              24.16
# 3  2020  2020-01-01  01:45:00  2020-01-01 01:45:00              24.18
# 4  2020  2020-01-01  02:15:00  2020-01-01 02:15:00              24.03
#
#    IR100_LST_TallAnt_degC  IR120_LST_TallAnt_degC  \
# 0                   19.72                   20.90
# 1                   19.37                   20.60
# 2                   20.00                   21.32
# 3                   20.23                   21.53
# 4                   19.36                   20.55
#
#    TSoil_2cm_FullSun_Tall.Antenna_degC  TSoil_5cm_FullSun_Tall.Antenna_degC  \
# 0                                25.75                                26.95
# 1                                25.40                                26.64
# ...

# %% [markdown]
# # creation NETCDF

# %% [markdown]
# ## Ouverture des fichiers, création de nouveaux jeux de données
#
# Créons un nouveau fichier netCDF vide nommé 'new.nc' dans le répertoire racine de notre projet 'data', ouvert pour l'écriture.
#
# Attention, ouvrir un fichier avec 'w' écrasera toutes les données existantes (à moins que `clobber=False` soit utilisé, auquel cas une exception est levée si le fichier existe déjà).
#
# - `mode='r'` est la valeur par défaut.
# - `mode='a'` ouvre un fichier existant et permet l'ajout (n'écrase pas les données existantes)
# - `format` peut être l'un des `NETCDF3_CLASSIC`, `NETCDF3_64BIT`, `NETCDF4_CLASSIC` ou `NETCDF4` (par défaut). `NETCDF4_CLASSIC` utilise HDF5 pour la couche de stockage sous-jacente (comme le fait `NETCDF4`) mais applique le modèle de données classique netCDF 3 afin que les données puissent être lues avec des clients plus anciens.

# %%
from netCDF4 import Dataset

# %%
# just to be safe, make sure dataset is not already open.
try: 

    #meteo soil
    nc_tsoilfs.close()
except: pass
#meteo soil
nc_tsoilfs = Dataset(path+file_year+'/OutdataFFlux_OpenOPSE_Soil_2020.nc',mode='w',format='NETCDF4')

# %% [markdown]
# ## creation des dimensions de chaque fichier netCDF

# %%
#meteo soil

## nc_tsoilfs = Dataset('/gdrive/MyDrive/NETCDF/soil_temp_profile_under_full_sun.nc',mode='w',format='NETCDF4') 
year_tsoilfs_dim = nc_tsoilfs.createDimension('year', None)
date_tsoilfs_dim = nc_tsoilfs.createDimension('Date', 366) 
hour_tsoilfs_dim = nc_tsoilfs.createDimension('Hour', 48)

# %% [markdown]
# ## creation des differentes variables

# %% [markdown]
# ### pivot

# %% [markdown]
# ### soil moist

# %%
# soil moist
## nc_tsoilfs

annee_tsoilfs = nc_tsoilfs.createVariable('year', np.float64, ('year',))
annee_tsoilfs.long_name = 'annee'

date_tsoilfs = nc_tsoilfs.createVariable('Date', str, ('Date',))
date_tsoilfs.long_name = 'Date'

hnum_tsoilfs = nc_tsoilfs.createVariable('Hour', str, ('Hour',))
hnum_tsoilfs.long_name = 'Heure dans la journée'
hnum_tsoilfs.units = 'heures dans la journée'


Tsoil_0cm_FullSun = nc_tsoilfs.createVariable('Tsoil_0cm_FullSun', np.float64, ('year','Date','Hour',))
Tsoil_0cm_FullSun.long_name = 'Soil surface temperature 0cm Full Sun'
Tsoil_0cm_FullSun.units = '°C'

IR100_LST_TallAnt_degC = nc_tsoilfs.createVariable('IR100_LST_TallAnt_degC', np.float64, ('year','Date','Hour',))
IR100_LST_TallAnt_degC.long_name = 'Land Surface Temperature at Tall Antenna with IR100'
IR100_LST_TallAnt_degC.units = '°C'

IR120_LST_TallAnt_degC = nc_tsoilfs.createVariable('IR120_LST_TallAnt_degC', np.float64, ('year','Date','Hour',))
IR120_LST_TallAnt_degC.long_name = 'Land Surface Temperature at Tall Antenna with IR120'
IR120_LST_TallAnt_degC.units = '°C'

TSoil_2cm_FullSun_Tall_Antenna_degC = nc_tsoilfs.createVariable('TSoil_2cm_FullSun_Tall.Antenna_degC', np.float64, ('year','Date','Hour',))
TSoil_2cm_FullSun_Tall_Antenna_degC.long_name = 'Soil temperature 2cm Full Sun'
TSoil_2cm_FullSun_Tall_Antenna_degC.units = '°C'

TSoil_5cm_FullSun_Tall_Antenna_degC = nc_tsoilfs.createVariable('TSoil_5cm_FullSun_Tall.Antenna_degC', np.float64, ('year','Date','Hour',))
TSoil_5cm_FullSun_Tall_Antenna_degC.long_name = 'Soil temperature 5cm Full Sun'
TSoil_5cm_FullSun_Tall_Antenna_degC.units = '°C'

TSoil_15cm_FullSun_Tall_Antenna_degC = nc_tsoilfs.createVariable('TSoil_15cm_FullSun_Tall.Antenna_degC', np.float64, ('year','Date','Hour',))
TSoil_15cm_FullSun_Tall_Antenna_degC.long_name = 'Soil temperature 15cm Full Sun'
TSoil_15cm_FullSun_Tall_Antenna_degC.units = '°C'

TSoil_30cm_FullSun_Tall_Antenna_degC = nc_tsoilfs.createVariable('TSoil_30cm_FullSun_Tall.Antenna_degC', np.float64, ('year','Date','Hour',))
TSoil_30cm_FullSun_Tall_Antenna_degC.long_name = 'Soil temperature 30cm Full Sun'
TSoil_30cm_FullSun_Tall_Antenna_degC.units = '°C'

TSoil_60cm_FullSun_Tall_Antenna_degC = nc_tsoilfs.createVariable('TSoil_60cm_FullSun_Tall.Antenna_degC', np.float64, ('year','Date','Hour',))
TSoil_60cm_FullSun_Tall_Antenna_degC.long_name = 'Soil temperature 60cm Full Sun'
TSoil_60cm_FullSun_Tall_Antenna_degC.units = '°C'

TSoil_100cm_FullSun_Tall_Antenna_degC = nc_tsoilfs.createVariable('TSoil_100cm_FullSun_Tall.Antenna_degC', np.float64, ('year','Date','Hour',))
TSoil_100cm_FullSun_Tall_Antenna_degC.long_name = 'Soil temperature 100cm Full Sun'
TSoil_100cm_FullSun_Tall_Antenna_degC.units = '°C'

TSoil_150cm_FullSun_Tall_Antenna_degC = nc_tsoilfs.createVariable('TSoil_150cm_FullSun_Tall.Antenna_degC', np.float64, ('year','Date','Hour',))
TSoil_150cm_FullSun_Tall_Antenna_degC.long_name = 'Soil temperature 150cm Full Sun'
TSoil_150cm_FullSun_Tall_Antenna_degC.units = '°C'

TSoil_200A_FullSun_Tall_Antenna_degC = nc_tsoilfs.createVariable('TSoil_200A_FullSun_Tall.Antenna_degC', np.float64, ('year','Date','Hour',))
TSoil_200A_FullSun_Tall_Antenna_degC.long_name = 'Soil temperature 200A Full Sun'
TSoil_200A_FullSun_Tall_Antenna_degC.units = '°C'

VW_15cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_15cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_15cm_FullSun_Tall_Antenna_fractCal.long_name = 'Volumetric water content 15cm Full Sun'
VW_15cm_FullSun_Tall_Antenna_fractCal.units = 'm3H2O m-3soil'

VW_30cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_30cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_30cm_FullSun_Tall_Antenna_fractCal.long_name = 'Volumetric water content 30cm Full Sun'
VW_30cm_FullSun_Tall_Antenna_fractCal.units = 'm3H2O m-3soil'

VW_50cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_50cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_50cm_FullSun_Tall_Antenna_fractCal.long_name = 'Volumetric water content 50cm Full Sun'
VW_50cm_FullSun_Tall_Antenna_fractCal.units = 'm3H2O m-3soil'

VW_75cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_75cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_75cm_FullSun_Tall_Antenna_fractCal.long_name = 'Volumetric water content 75cm Full Sun'
VW_75cm_FullSun_Tall_Antenna_fractCal.units = 'm3H2O m-3soil'

VW_100cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_100cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_100cm_FullSun_Tall_Antenna_fractCal.long_name = 'Volumetric water content 100cm Full Sun'
VW_100cm_FullSun_Tall_Antenna_fractCal.units = 'm3H2O m-3soil'

VW_125cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_125cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_125cm_FullSun_Tall_Antenna_fractCal.long_name = 'Volumetric water content 125cm Full Sun'
VW_125cm_FullSun_Tall_Antenna_fractCal.units = 'm3H2O m-3soil'

VW_150cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_150cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_150cm_FullSun_Tall_Antenna_fractCal.long_name = 'Volumetric water content 150cm Full Sun'
VW_150cm_FullSun_Tall_Antenna_fractCal.units = 'm3H2O m-3soil'

VW_175cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_175cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_175cm_FullSun_Tall_Antenna_fractCal.long_name = 'Volumetric water content 175cm Full Sun'
VW_175cm_FullSun_Tall_Antenna_fractCal.units = 'm3H2O m-3soil'

VW_200cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_200cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_200cm_FullSun_Tall_Antenna_fractCal.long_name = 'Volumetric water content 200cm Full Sun'
VW_200cm_FullSun_Tall_Antenna_fractCal.units = 'm3H2O m-3soil'

# %% [markdown]
# ## ecriture des données

# %%
def getData365(data, colonne, jdan=365):
    val = data[colonne]
    return np.array(val).reshape(1,jdan,48)

# %%
## nc_msSmallAnt 
annee = data['Year'].unique()
date = data['Date_fac'].unique()
hnum = data['Hour_fac'].unique()

# %% [markdown]
# ## soil moist

# %%
# soil moist
## nc_tsoilfs

#annee_tsoilfs = nc_tsoilfs.createVariable('year', np.float64, ('year',))
annee_tsoilfs[:] = annee

#doy_tsoilfs = nc_tsoilfs.createVariable('doy', np.float64, ('DOY',))
date_tsoilfs[:] = date

#hnum_tsoilfs = nc_tsoilfs.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_tsoilfs[:] = hnum


#Tsoil_0cm_FullSun = nc_tsoilfs.createVariable('Tsoil_0cm_FullSun', np.float64, ('year','Date','Hour',))
Tsoil_0cm_FullSun[:,:,:] = getData365(data, 'Tsoil_0cm_FullSun', jdan=366)

#IR100_LST_TallAnt_degC = nc_tsoilfs.createVariable('IR100_LST_TallAnt_degC', np.float64, ('year','Date','Hour',))
IR100_LST_TallAnt_degC[:,:,:] = getData365(data, 'IR100_LST_TallAnt_degC', jdan=366)

#IR120_LST_TallAnt_degC = nc_tsoilfs.createVariable('IR120_LST_TallAnt_degC', np.float64, ('year','Date','Hour',))
IR120_LST_TallAnt_degC[:,:,:] = getData365(data, 'IR120_LST_TallAnt_degC', jdan=366)

#TSoil_2cm_FullSun_Tall_Antenna_degC = nc_tsoilfs.createVariable('TSoil_2cm_FullSun_Tall.Antenna_degC', np.float64, ('year','Date','Hour',))
TSoil_2cm_FullSun_Tall_Antenna_degC[:,:,:] = getData365(data, 'TSoil_2cm_FullSun_Tall.Antenna_degC', jdan=366)

#TSoil_5cm_FullSun_Tall_Antenna_degC = nc_tsoilfs.createVariable('TSoil_5cm_FullSun_Tall.Antenna_degC', np.float64, ('year','Date','Hour',))
TSoil_5cm_FullSun_Tall_Antenna_degC[:,:,:] = getData365(data, 'TSoil_5cm_FullSun_Tall.Antenna_degC', jdan=366)

#TSoil_15cm_FullSun_Tall_Antenna_degC = nc_tsoilfs.createVariable('TSoil_15cm_FullSun_Tall.Antenna_degC', np.float64, ('year','Date','Hour',))
TSoil_15cm_FullSun_Tall_Antenna_degC[:,:,:] = getData365(data, 'TSoil_15cm_FullSun_Tall.Antenna_degC', jdan=366)

#TSoil_30cm_FullSun_Tall_Antenna_degC = nc_tsoilfs.createVariable('TSoil_30cm_FullSun_Tall.Antenna_degC', np.float64, ('year','Date','Hour',))
TSoil_30cm_FullSun_Tall_Antenna_degC[:,:,:] = getData365(data, 'TSoil_30cm_FullSun_Tall.Antenna_degC', jdan=366)

#TSoil_60cm_FullSun_Tall_Antenna_degC = nc_tsoilfs.createVariable('TSoil_60cm_FullSun_Tall.Antenna_degC', np.float64, ('year','Date','Hour',))
TSoil_60cm_FullSun_Tall_Antenna_degC[:,:,:] = getData365(data, 'TSoil_60cm_FullSun_Tall.Antenna_degC', jdan=366)

#TSoil_100cm_FullSun_Tall_Antenna_degC = nc_tsoilfs.createVariable('TSoil_100cm_FullSun_Tall.Antenna_degC', np.float64, ('year','Date','Hour',))
TSoil_100cm_FullSun_Tall_Antenna_degC[:,:,:] = getData365(data, 'TSoil_100cm_FullSun_Tall.Antenna_degC', jdan=366)

#TSoil_150cm_FullSun_Tall_Antenna_degC = nc_tsoilfs.createVariable('TSoil_150cm_FullSun_Tall.Antenna_degC', np.float64, ('year','Date','Hour',))
TSoil_150cm_FullSun_Tall_Antenna_degC[:,:,:] = getData365(data, 'TSoil_150cm_FullSun_Tall.Antenna_degC', jdan=366)

#TSoil_200A_FullSun_Tall_Antenna_degC = nc_tsoilfs.createVariable('TSoil_200A_FullSun_Tall.Antenna_degC', np.float64, ('year','Date','Hour',))
TSoil_200A_FullSun_Tall_Antenna_degC[:,:,:] = getData365(data, 'Tsoil_200A_FullSun_Tall.Antenna_degC', jdan=366)

#VW_15cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_15cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_15cm_FullSun_Tall_Antenna_fractCal[:,:,:] = getData365(data, 'VW_15cm_FullSun_Tall.Antenna_fractCal', jdan=366)

#VW_30cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_30cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_30cm_FullSun_Tall_Antenna_fractCal[:,:,:] = getData365(data, 'VW_30cm_FullSun_Tall.Antenna_fractCal', jdan=366)

#VW_50cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_50cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_50cm_FullSun_Tall_Antenna_fractCal[:,:,:] = getData365(data, 'VW_50cm_FullSun_Tall.Antenna_fractCal', jdan=366)

#VW_75cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_75cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_75cm_FullSun_Tall_Antenna_fractCal[:,:,:] = getData365(data, 'VW_75cm_FullSun_Tall.Antenna_fractCal', jdan=366)

#VW_100cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_100cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_100cm_FullSun_Tall_Antenna_fractCal[:,:,:] = getData365(data, 'VW_100cm_FullSun_Tall.Antenna_fractCal', jdan=366)

#VW_125cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_125cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_125cm_FullSun_Tall_Antenna_fractCal[:,:,:] = getData365(data, 'VW_125cm_FullSun_Tall.Antenna_fractCal', jdan=366)

#VW_150cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_150cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_150cm_FullSun_Tall_Antenna_fractCal[:,:,:] = getData365(data, 'VW_150cm_FullSun_Tall.Antenna_fractCal', jdan=366)

#VW_175cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_175cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_175cm_FullSun_Tall_Antenna_fractCal[:,:,:] = getData365(data, 'VW_175cm_FullSun_Tall.Antenna_fractCal', jdan=366)

#VW_200cm_FullSun_Tall_Antenna_fractCal = nc_tsoilfs.createVariable('VW_200cm_FullSun_Tall.Antenna_fractCal', np.float64, ('year','Date','Hour',))
VW_200cm_FullSun_Tall_Antenna_fractCal[:,:,:] = getData365(data, 'VW_200cm_FullSun_Tall.Antenna_fractCal', jdan=366)

# %% [markdown]
# ### fermeture des fichiers netcdf

# %%
#meteo soil
nc_tsoilfs.close()
print('Dataset is closed!')
# Out:
# Dataset is closed!
