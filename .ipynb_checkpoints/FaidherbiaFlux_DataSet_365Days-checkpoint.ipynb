# %% [markdown]
# # Traitement du dataset

# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv("~/Documents/OPENOPSE/data/Olivier Roupsard/updated/dataset/Outdata_Time_Meteo_Flux_Tsoil_TDR_LAI_Puits2_2019.csv")
data.head()
# Out:
#    Year  DOY  Hournumeric  Rn_20m_Wm2  PARtot_20m_mE  Tair_20m_degC  \
# 0  2019    1          0.5      -58.78       4.704876          23.61
# 1  2019    1          1.0      -56.51       4.941079          23.12
# 2  2019    1          1.5      -50.08       4.845159          22.82
# 3  2019    1          2.0      -46.49       4.798398          22.75
# 4  2019    1          2.5      -43.94       4.854751          22.61
#
#    Rh_20m_pc  WindSpeed_20m_ms1  WindDir_20m_deg  Rain_mmsemih  ...  \
# 0      38.01              2.550             10.0           0.0  ...
# 1      40.78              2.523              2.0           0.0  ...
# 2      41.45              2.396            336.0           0.0  ...
# 3      41.27              2.206             10.0           0.0  ...
# 4      41.19              2.151            342.0           0.0  ...
#
#    SoilVWC_Well2_Shaded_40cm_m3H2Om3soil  \
# 0                                    NaN
# 1                                    NaN
# ...

# %%
data = data.fillna(float('nan'))

# %%
data.head()
# Out:
#    Year  DOY  Hournumeric  Rn_20m_Wm2  PARtot_20m_mE  Tair_20m_degC  \
# 0  2019    1          0.5      -58.78       4.704876          23.61
# 1  2019    1          1.0      -56.51       4.941079          23.12
# 2  2019    1          1.5      -50.08       4.845159          22.82
# 3  2019    1          2.0      -46.49       4.798398          22.75
# 4  2019    1          2.5      -43.94       4.854751          22.61
#
#    Rh_20m_pc  WindSpeed_20m_ms1  WindDir_20m_deg  Rain_mmsemih  ...  \
# 0      38.01              2.550             10.0           0.0  ...
# 1      40.78              2.523              2.0           0.0  ...
# 2      41.45              2.396            336.0           0.0  ...
# 3      41.27              2.206             10.0           0.0  ...
# 4      41.19              2.151            342.0           0.0  ...
#
#    SoilVWC_Well2_Shaded_40cm_m3H2Om3soil  \
# 0                                    NaN
# 1                                    NaN
# ...

# %% [markdown]
# # creation des dataframe

# %% [markdown]
# ## definition des colonnes de chaque jeu de donnees de catalogue

# %%
pivot = ['Year','DOY','Date_fac','Hour_fac']

# soil moist
tsoilfs = pivot + ['Tsoil_0cm_FullSun','TSoil_2cm_FullSun_Tall.Antenna_degC','TSoil_5cm_FullSun_Tall.Antenna_degC',
                   'TSoil_15cm_FullSun_Tall.Antenna_degC','TSoil_30cm_FullSun_Tall.Antenna_degC',
                   'TSoil_60cm_FullSun_Tall.Antenna_degC','TSoil_100cm_FullSun_Tall.Antenna_degC',
                   'TSoil_150cm_FullSun_Tall.Antenna_degC','Tsoil_200A_FullSun_Tall.Antenna_degC']

vwfs = pivot + ['VW_15cm_FullSun_Tall.Antenna_fractCal','VW_30cm_FullSun_Tall.Antenna_fractCal',
                'VW_50cm_FullSun_Tall.Antenna_fractCal','VW_75cm_FullSun_Tall.Antenna_fractCal',
                'VW_100cm_FullSun_Tall.Antenna_fractCal','VW_125cm_FullSun_Tall.Antenna_fractCal',
                'VW_150cm_FullSun_Tall.Antenna_fractCal','VW_175cm_FullSun_Tall.Antenna_fractCal',
                'VW_200cm_FullSun_Tall.Antenna_fractCal']

tsoilwell = pivot + ['SoilT_Well2_Shaded_20cm_degC','SoilT_Well2_Shaded_40cm_degC',
                     'SoilT_Well2_Shaded_60cm_degC','SoilT_Well2_Shaded_80cm_degC',
                     'SoilT_Well2_Shaded_120cm_degC', 'SoilT_Well2_Shaded_140cm_degC',
                     'SoilT_Well2_Shaded_160cm_degC','SoilT_Well2_Shaded_180cm_degC',
                     'SoilT_Well2_Shaded_280cm_degC','SoilT_Well2_Shaded_380cm_degC',
                     'SoilT_Well2_Shaded_480cm_degC']

vwwell = pivot + ['SoilVWC_Well2_Shaded_20cm_m3H2Om3soil','SoilVWC_Well2_Shaded_40cm_m3H2Om3soil',
                  'SoilVWC_Well2_Shaded_60cm_m3H2Om3soil','SoilVWC_Well2_Shaded_80cm_m3H2Om3soil',
                  'SoilVWC_Well2_Shaded_120cm_m3H2Om3soil','SoilVWC_Well2_Shaded_140cm_m3H2Om3soil',
                  'SoilVWC_Well2_Shaded_160cm_m3H2Om3soil','SoilVWC_Well2_Shaded_180cm_m3H2Om3soil',
                  'SoilVWC_Well2_Shaded_280cm_m3H2Om3soil','SoilVWC_Well2_Shaded_380cm_m3H2Om3soil',
                  'SoilVWC_Well2_Shaded_480cm_m3H2Om3soil']



#tree
leafRate = pivot + ['Leaf_Fa_1_pc','Leaf_Fa_2_pc','Leaf_Fa_3_pc','Leaf_Fa_4_pc','Leaf_Fa_5_pc',
                    'Leaf_Fa_6_pc','Leaf_Fa_7_pc','Leaf_Fa_8_pc','Leaf_Fa_9_pc','Leaf_Fa_10_pc',
                    'Leaf_Fa_11_pc','Leaf_Fa_12_pc','Leaf_Fa_27_pc','Leaf_Fa_28_pc','Leaf_Fa_46_pc']

leafAD = pivot + ['LAD_Fa_1_m2leafm3','LAD_Fa_2_m2leafm3','LAD_Fa_3_m2leafm3','LAD_Fa_4_m2leafm3',
                  'LAD_Fa_5_m2leafm3','LAD_Fa_6_m2leafm3','LAD_Fa_7_m2leafm3','LAD_Fa_8_m2leafm3',
                  'LAD_Fa_9_m2leafm3','LAD_Fa_10_m2leafm3','LAD_Fa_11_m2leafm3','LAD_Fa_12_m2leafm3',
                  'LAD_Fa_27_m2leafm3','LAD_Fa_28_m2leafm3','LAD_Fa_46_m2leafm3']

leafAPT = pivot + ['LA_Fa_1_m2leaftree','LA_Fa_2_m2leaftree','LA_Fa_3_m2leaftree','LA_Fa_4_m2leaftree',
                   'LA_Fa_5_m2leaftree','LA_Fa_6_m2leaftree','LA_Fa_7_m2leaftree','LA_Fa_8_m2leaftree',
                   'LA_Fa_9_m2leaftree','LA_Fa_10_m2leaftree','LA_Fa_11_m2leaftree','LA_Fa_12_m2leaftree',
                   'LA_Fa_27_m2leaftree','LA_Fa_28_m2leaftree','LA_Fa_46_m2leaftree']

dripLLAI = pivot + ['DripLineLAI_Fa_1_m2leafm2','DripLineLAI_Fa_2_m2leafm2','DripLineLAI_Fa_3_m2leafm2',
                    'DripLineLAI_Fa_4_m2leafm2','DripLineLAI_Fa_5_m2leafm2','DripLineLAI_Fa_6_m2leafm2',
                    'DripLineLAI_Fa_7_m2leafm2','DripLineLAI_Fa_8_m2leafm2','DripLineLAI_Fa_9_m2leafm2',
                    'DripLineLAI_Fa_10_m2leafm2','DripLineLAI_Fa_11_m2leafm2','DripLineLAI_Fa_12_m2leafm2',
                    'DripLineLAI_Fa_27_m2leafm2','DripLineLAI_Fa_28_m2leafm2','DripLineLAI_Fa_46_m2leafm2',
                   'Mean_Tree_LAI_Towerplot_m2leafm2']

CWNDVI = pivot + ['CropWeedNDVI']

#les elements ajoutés

LaicwAntPlotScale = pivot + ['CropWeedLAI']

LaiTreecwAntPlotScale = pivot + ['TreeandCropWeedLAI_m2leafm2']

woodW = pivot + ['WoodVWC_1_tree5_pc','WoodVWC_2_tree5_pc','WoodT_1_tree5_degC','WoodT_2_tree5_degC']

netRadiation = pivot + ['Rn_20m_Wm2'] #,'Rn_20m_Wm2.Gf','Rn_20m_Wm2_Lagouarde_Gf'


# meteo
msSmallAnt = pivot + ['Tair_2m_SmallAnt_degC',
                   'Rh_2m_SmallAnt_pc','WS_2m_SmallAntSonic_ms','VPD_2m_hPa.Gf','ETo_2m_mmsemih_Gf']

msTallAnt = pivot + ['PARtot_20m_mE','NDVI_TallAnt_crop','Tair_20m_degC','Rh_20m_pc','WindSpeed_20m_ms1',
                   'WindDir_20m_deg','Rain_mmsemih','P_20m_hPa','eVais_20m_hPa','VPD_20m_hPa','PARtot_20m_mE_filt',
                   'Rg_estim_20m.Gf','PARDiff.ModEmpir.Gf','Diff.Fraction.ModEmpir.Gf','IR100_LST_TallAnt_degC',
                   'IR120_LST_TallAnt_degC','ETo_20m_mmh_Gf']

fluxTallAnt = pivot + ['NEE_micmolm2s_20m','LE_Wm2__20m','H_Wm2_20m','Ustar_Thres_20m','Reco_MR_micmolm2s_20m',
                      'GPP_MR_micmolm2s_20m','GPP_MR_Gfqc_20m','Reco_DT_micmolm2s_20m','GPP_DT_micmolm2s_20m',
                      'GPP_DT_uStar_SD_micmolm2s_20m','LE_Gf_Wm2_20m','LE_Gfqc_20m','H_Gf_20m','H_Gfqc_20m']


#smpp1920 = pivot + ['IR100_LST_TallAnt_degC','IR120_LST_TallAnt_degC']





# Fin des elements ajoutés



#solar time
#solarT = pivot + ['SolTime','SolDecl', 'SolElev', 'SolAzim', 'sinbeta', 'DayNight','RgbyRaNonCloudiness','Spitters$DiffuseFrSpitters']

#co2 h2o flux
#netCo2Eco = pivot + ['WS_2m_SmallAntSonic_ms_filt', 'WS_2m_SmallAntSonic_ms.Gf','R_ref_uStar_micmolm2s_20m',
 #                    'NEE_micmolm2s_20m','Ustar_Gfqc_20m_20m','NEE_Gf_micmolm2s_20m','NEE_Gfqc_20m',
  #                   'NEE_Gfsd_micmolm2s_20m', 'NEE_U05_Gf_micmolm2s_20m', 'NEE_U50_Gf_micmolm2s_20m','GPP_MR_Gfqc_20m',
   #                  'NEE_U95_Gf_micmolm2s_20m', 'Reco_MR_micmolm2s_20m','GPP_MR_micmolm2s_20m', 'Reco_DT_micmolm2s_20m',
    #                 'Reco_DT_uStar_SD_micmolm2s_20m','GPP_DT_micmolm2s_20m', 'GPP_DT_uStar_SD_micmolm2s_20m']

#heatFMGaps = pivot + ['LE_Wm2__20m','H_Wm2_20m']

#windF = pivot + ['Ustar_Thres_20m','WindSpeed_20m_ms1','WindDir_20m_deg']

# %% [markdown]
# ## segmentation du jeu de données

# %%
#meteo soil

df_tsoilfs = data[tsoilfs]
df_vwfs = data[vwfs]
df_tsoilwell = data[tsoilwell]
df_vwwell = data[vwwell]

#tree

df_leafRate = data[leafRate]
df_leafAD = data[leafAD]
df_leafAPT = data[leafAPT]
df_dripLLAI = data[dripLLAI]
df_CWNDVI = data[CWNDVI]
df_LaicwAntPlotScale = data[LaicwAntPlotScale]
df_LaiTreecwAntPlotScale = data[LaiTreecwAntPlotScale]
df_woodW = data[woodW]
df_netRadiation = data[netRadiation]
# meteo
df_msSmallAnt = data[msSmallAnt]
df_msTallAnt = data[msTallAnt]
df_fluxTallAnt = data[fluxTallAnt]

# %% [markdown]
# # creation NETCDF

# %% [markdown]
# ## Ouverture des fichiers, création de nouveaux jeux de données
#
# Créons un nouveau fichier netCDF vide nommé 'new.nc' dans le répertoire racine de notre projet 'data', ouvert pour l'écriture.
#
# Attention, ouvrir un fichier avec 'w' écrasera toutes les données existantes (à moins que `clobber=False` soit utilisé, auquel cas une exception est levée si le fichier existe déjà).
#
# - `mode='r'` est la valeur par défaut.
# - `mode='a'` ouvre un fichier existant et permet l'ajout (n'écrase pas les données existantes)
# - `format` peut être l'un des `NETCDF3_CLASSIC`, `NETCDF3_64BIT`, `NETCDF4_CLASSIC` ou `NETCDF4` (par défaut). `NETCDF4_CLASSIC` utilise HDF5 pour la couche de stockage sous-jacente (comme le fait `NETCDF4`) mais applique le modèle de données classique netCDF 3 afin que les données puissent être lues avec des clients plus anciens.

# %%
from netCDF4 import Dataset

# %%
file_year='2019'

# %%
# just to be safe, make sure dataset is not already open.
try: 

    #meteo soil
    nc_tsoilfs.close()
    nc_vwfs.close()
    nc_tsoilwell.close()
    nc_vwwell.close()

    #tree
    nc_leafRate.close()
    nc_leafAD.close()
    nc_leafAPT.close()
    nc_dripLLAI.close()
    nc_CWNDVI.close()
    nc_LaicwAntPlotScale.close()
    nc_LaiTreecwAntPlotScale.close()
    nc_woodW.close()
    nc_netRadiation.close()

    # meteo
    nc_msSmallAnt.close()
    nc_msTallAnt.close()
    nc_fluxTallAnt.close()
except: pass
#meteo soil
nc_tsoilfs = Dataset('./output/'+file_year+'/soil_temp_profile_under_full_sun_0_to_-2m_'+file_year+'.nc',mode='w',format='NETCDF4') 
nc_vwfs = Dataset('./output/'+file_year+'/volumetric_water_content_under_full_sun_0_to_-2m_'+file_year+'.nc',mode='w',format='NETCDF4') 
nc_tsoilwell = Dataset('./output/'+file_year+'/soil_temp_profile_in_the_wells2_-0,2_to_-4,8m_'+file_year+'.nc',mode='w',format='NETCDF4') 
nc_vwwell = Dataset('./output/'+file_year+'/volumetric_water_content_in_the_wells2_-0,2_to_-4,8m_'+file_year+'.nc',mode='w',format='NETCDF4') 

#tree
nc_leafRate = Dataset('./output/'+file_year+'/Leafing_rate_'+file_year+'.nc',mode='w',format='NETCDF4') 
nc_leafAD = Dataset('./output/'+file_year+'/leaf_area_density_'+file_year+'.nc',mode='w',format='NETCDF4') 
nc_leafAPT = Dataset('./output/'+file_year+'/leaf_area_per_tree_'+file_year+'.nc',mode='w',format='NETCDF4') 
nc_dripLLAI = Dataset('./output/'+file_year+'/drip_line_leaf_area_index_'+file_year+'.nc',mode='w',format='NETCDF4') 
nc_CWNDVI = Dataset('./output/'+file_year+'/crops_weeds_NDVI_full_sun_conditions_'+file_year+'.nc',mode='w',format='NETCDF4') 
nc_LaicwAntPlotScale = Dataset('./output/'+file_year+'/leaf_area_index_crops_weeds_at_the_antenna_plot_scale_'+file_year+'.nc',mode='w',format='NETCDF4') 
nc_LaiTreecwAntPlotScale = Dataset('./output/'+file_year+'/leaf_area_index_of_tree_crops_weeds_at_the_antenna_plot_scale_'+file_year+'.nc',mode='w',format='NETCDF4') 
nc_woodW = Dataset('./output/'+file_year+'/wood_weather_'+file_year+'.nc',mode='w',format='NETCDF4') 
nc_netRadiation = Dataset('./output/'+file_year+'/net_radiation_at_30m_high_'+file_year+'.nc',mode='w',format='NETCDF4') 

# meteo
nc_msSmallAnt = Dataset('./output/'+file_year+'/meteo_station_small_antenna_at_2m_high_'+file_year+'.nc',mode='w',format='NETCDF4') 
nc_msTallAnt = Dataset('./output/'+file_year+'/meteo_station_tall_antenna_at_20m_high_'+file_year+'.nc',mode='w',format='NETCDF4') 
nc_fluxTallAnt = Dataset('./output/'+file_year+'/fluxes_tall_antenna_at_20m_high_'+file_year+'.nc',mode='w',format='NETCDF4')

# %% [markdown]
# ## creation des dimensions de chaque fichier netCDF

# %%
#meteo soil

## nc_tsoilfs = Dataset('/gdrive/MyDrive/NETCDF/soil_temp_profile_under_full_sun.nc',mode='w',format='NETCDF4') 
year_tsoilfs_dim = nc_tsoilfs.createDimension('year', None)
doy_tsoilfs_dim = nc_tsoilfs.createDimension('DOY', 365) 
hour_tsoilfs_dim = nc_tsoilfs.createDimension('Hournumeric', 48) 

## nc_vwfs = Dataset('/gdrive/MyDrive/NETCDF/volumetric_water_content_under_full_sun.nc',mode='w',format='NETCDF4') 
year_vwfs_dim = nc_vwfs.createDimension('year', None)
doy_vwfs_dim = nc_vwfs.createDimension('DOY', 365) 
hour_vwfs_dim = nc_vwfs.createDimension('Hournumeric', 48) 

## nc_tsoilwell = Dataset('/gdrive/MyDrive/NETCDF/soil_temp_profile_in_the_wells.nc',mode='w',format='NETCDF4') 
year_tsoilwell_dim = nc_tsoilwell.createDimension('year', None)
doy_tsoilwell_dim = nc_tsoilwell.createDimension('DOY', 365) 
hour_tsoilwell_dim = nc_tsoilwell.createDimension('Hournumeric', 48) 

## nc_vwwell = Dataset('/gdrive/MyDrive/NETCDF/volumetric_water_content_in_the_wells.nc',mode='w',format='NETCDF4') 
year_vwwell_dim = nc_vwwell.createDimension('year', None)
doy_vwwell_dim = nc_vwwell.createDimension('DOY', 365) 
hour_vwwell_dim = nc_vwwell.createDimension('Hournumeric', 48) 


#tree

## nc_leafRate = Dataset('Leafing_rate.nc',mode='w',format='NETCDF4') 
year_leafRate_dim = nc_leafRate.createDimension('year', None)
doy_leafRate_dim = nc_leafRate.createDimension('DOY', 365) 
hour_leafRate_dim = nc_leafRate.createDimension('Hournumeric', 48) 

## nc_leafAD = Dataset('/gdrive/MyDrive/NETCDF/leaf_area_density.nc',mode='w',format='NETCDF4') 
year_leafAD_dim = nc_leafAD.createDimension('year', None)
doy_leafAD_dim = nc_leafAD.createDimension('DOY', 365) 
hour_leafAD_dim = nc_leafAD.createDimension('Hournumeric', 48) 

## nc_leafAPT = Dataset('/gdrive/MyDrive/NETCDF/leaf_area_per_tree.nc',mode='w',format='NETCDF4') 
year_leafAPT_dim = nc_leafAPT.createDimension('year', None)
doy_leafAPT_dim = nc_leafAPT.createDimension('DOY', 365) 
hour_leafAPT_dim = nc_leafAPT.createDimension('Hournumeric', 48) 

## nc_dripLLAI = Dataset('/gdrive/MyDrive/NETCDF/drip_line_leaf_area_index.nc',mode='w',format='NETCDF4') 
year_dripLLAI_dim = nc_dripLLAI.createDimension('year', None)
doy_dripLLAI_dim = nc_dripLLAI.createDimension('DOY', 365) 
hour_dripLLAI_dim = nc_dripLLAI.createDimension('Hournumeric', 48) 

## nc_CWNDVI = Dataset('crops_weeds_NDVI_full_sun_conditions.nc',mode='w',format='NETCDF4')  
year_CWNDVI_dim = nc_CWNDVI.createDimension('year', None)
doy_CWNDVI_dim = nc_CWNDVI.createDimension('DOY', 365) 
hour_CWNDVI_dim = nc_CWNDVI.createDimension('Hournumeric', 48) 

##nc_LaicwAntPlotScale = Dataset('leaf_area_index_crops_weeds_at_the_antenna_plot_scale.nc',mode='w',format='NETCDF4') 
year_LaicwAntPlotScale_dim = nc_LaicwAntPlotScale.createDimension('year', None)
doy_LaicwAntPlotScale_dim = nc_LaicwAntPlotScale.createDimension('DOY', 365) 
hour_LaicwAntPlotScale_dim = nc_LaicwAntPlotScale.createDimension('Hournumeric', 48)

##nc_LaiTreecwAntPlotScale = Dataset('leaf_area_index_of_tree_crops_weeds_at_the_antenna_plot_scale.nc',mode='w',format='NETCDF4') 
year_LaiTreecwAntPlotScale_dim = nc_LaiTreecwAntPlotScale.createDimension('year', None)
doy_LaiTreecwAntPlotScale_dim = nc_LaiTreecwAntPlotScale.createDimension('DOY', 365) 
hour_LaiTreecwAntPlotScale_dim = nc_LaiTreecwAntPlotScale.createDimension('Hournumeric', 48)

## nc_woodW = Dataset('/gdrive/MyDrive/NETCDF/wood_weather.nc',mode='w',format='NETCDF4') 
year_woodW_dim = nc_woodW.createDimension('year', None)
doy_woodW_dim = nc_woodW.createDimension('DOY', 365) 
hour_woodW_dim = nc_woodW.createDimension('Hournumeric', 48) 

##nc_netRadiation = Dataset('net_radiation_30m_high.nc',mode='w',format='NETCDF4') 
year_netRadiation_dim = nc_netRadiation.createDimension('year', None)
doy_netRadiation_dim = nc_netRadiation.createDimension('DOY', 365) 
hour_netRadiation_dim = nc_netRadiation.createDimension('Hournumeric', 48) 


# meteo
## nc_msSmallAnt = Dataset('meteo_station_small_antenna_at_2m_high.nc',mode='w',format='NETCDF4')  
year_msSmallAnt_dim = nc_msSmallAnt.createDimension('year', None)
doy_msSmallAnt_dim = nc_msSmallAnt.createDimension('DOY', 365) 
hour_msSmallAnt_dim = nc_msSmallAnt.createDimension('Hournumeric', 48) 

## nc_msTallAnt = Dataset('meteo_station_tall_antenna_at_20m_high.nc',mode='w',format='NETCDF4')  
year_msTallAnt_dim = nc_msTallAnt.createDimension('year', None)
doy_msTallAnt_dim = nc_msTallAnt.createDimension('DOY', 365) 
hour_msTallAnt_dim = nc_msTallAnt.createDimension('Hournumeric', 48) 

## nc_fluxTallAnt = Dataset('fluxes_tall_antenna_at_20m_high.nc',mode='w',format='NETCDF4') 
year_fluxTallAnt_dim = nc_fluxTallAnt.createDimension('year', None)
doy_fluxTallAnt_dim = nc_fluxTallAnt.createDimension('DOY', 365) 
hour_fluxTallAnt_dim = nc_fluxTallAnt.createDimension('Hournumeric', 48)

# %% [markdown]
# ## creation des differentes variables

# %% [markdown]
# ### pivot

# %% [markdown]
# ### soil moist

# %%
# soil moist
## nc_tsoilfs

annee_tsoilfs = nc_tsoilfs.createVariable('year', np.float64, ('year',))
annee_tsoilfs.long_name = 'annee'

doy_tsoilfs = nc_tsoilfs.createVariable('doy', np.float64, ('DOY',))
doy_tsoilfs.long_name = 'Day Of Year / numero du jour dans année (1-365)'

hnum_tsoilfs = nc_tsoilfs.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_tsoilfs.long_name = 'Heure numerique dans la journée'
hnum_tsoilfs.units = 'heures dans la journée'


Tsoil_0cm_FullSun = nc_tsoilfs.createVariable('Tsoil_0cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
Tsoil_0cm_FullSun.long_name = 'Soil temperature profile under full sun, 0cm'
Tsoil_0cm_FullSun.units = '°C'

TSoil_2cm_FullSun = nc_tsoilfs.createVariable('TSoil_2cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
TSoil_2cm_FullSun.long_name = 'Soil temperature profile under full sun, 2cm'
TSoil_2cm_FullSun.units = '°C (degré celcius)'

TSoil_5cm_FullSun = nc_tsoilfs.createVariable('TSoil_5cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
TSoil_5cm_FullSun.long_name = 'Soil temperature profile under full sun, 5cm'
TSoil_5cm_FullSun.units = '°C (degré celcius)'

TSoil_15cm_FullSun = nc_tsoilfs.createVariable('TSoil_15cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
TSoil_15cm_FullSun.long_name = 'Soil temperature profile under full sun, 15cm'
TSoil_15cm_FullSun.units = '°C (degré celcius)'

TSoil_30cm_FullSun = nc_tsoilfs.createVariable('TSoil_30cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
TSoil_30cm_FullSun.long_name = 'Soil temperature profile under full sun, 30cm'
TSoil_30cm_FullSun.units = '°C (degré celcius)'

TSoil_60cm_FullSun = nc_tsoilfs.createVariable('TSoil_60cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
TSoil_60cm_FullSun.long_name = 'Soil temperature profile under full sun, 60cm'
TSoil_60cm_FullSun.units = '°C (degré celcius)'

TSoil_100cm_FullSun = nc_tsoilfs.createVariable('TSoil_100cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
TSoil_100cm_FullSun.long_name = 'Soil temperature profile under full sun, 100cm'
TSoil_100cm_FullSun.units = '°C (degré celcius)'

TSoil_150cm_FullSun = nc_tsoilfs.createVariable('TSoil_150cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
TSoil_150cm_FullSun.long_name = 'Soil temperature profile under full sun, 150cm'
TSoil_150cm_FullSun.units = '°C (degré celcius)'

Tsoil_200A_FullSun = nc_tsoilfs.createVariable('Tsoil_200A_FullSun', np.float64, ('year','DOY','Hournumeric',))
Tsoil_200A_FullSun.long_name = 'Soil temperature profile under full sun, 200cm'
Tsoil_200A_FullSun.units = '°C (degré celcius)'

## nc_vwfs

annee_vwfs = nc_vwfs.createVariable('year', np.float64, ('year',))
annee_vwfs.long_name = 'annee'

doy_vwfs = nc_vwfs.createVariable('doy', np.float64, ('DOY',))
doy_vwfs.long_name = 'Day Of Year / numero du jour dans année (1-365)'

hnum_vwfs = nc_vwfs.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_vwfs.long_name = 'Heure numerique dans la journée'
hnum_vwfs.units = 'heures dans la journée'

VW_15cm_FullSun = nc_vwfs.createVariable('VW_15cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_15cm_FullSun.long_name = 'Volumetric water content under full sun, 15cm'
VW_15cm_FullSun.units = 'm3H2O m-3soil'

VW_30cm_FullSun = nc_vwfs.createVariable('VW_30cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_30cm_FullSun.long_name = 'Volumetric water content under full sun, 30cm'
VW_30cm_FullSun.units = 'm3H2O m-3soil'

VW_50cm_FullSun = nc_vwfs.createVariable('VW_50cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_50cm_FullSun.long_name = 'Volumetric water content under full sun, 50cm'
VW_50cm_FullSun.units = 'm3H2O m-3soil'

VW_75cm_FullSun = nc_vwfs.createVariable('VW_75cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_75cm_FullSun.long_name = 'Teneur en eau volumétrique à 75 cm de profondeur - plein soleil'
VW_75cm_FullSun.units = 'm3H2O m-3soil'

VW_100cm_FullSun = nc_vwfs.createVariable('VW_100cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_100cm_FullSun.long_name = 'Volumetric water content under full sun, 100cm'
VW_100cm_FullSun.units = 'm3H2O m-3soil'

VW_125cm_FullSun = nc_vwfs.createVariable('VW_125cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_125cm_FullSun.long_name = 'Volumetric water content under full sun, 125cm'
VW_125cm_FullSun.units = 'm3H2O m-3soil'

VW_150cm_FullSun = nc_vwfs.createVariable('VW_150cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_150cm_FullSun.long_name = 'Volumetric water content under full sun, 150cm'
VW_150cm_FullSun.units = 'm3H2O m-3soil'

VW_175cm_FullSun = nc_vwfs.createVariable('VW_175cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_175cm_FullSun.long_name = 'Volumetric water content under full sun, 175cm'
VW_175cm_FullSun.units = 'm3H2O m-3soil'

VW_200cm_FullSun = nc_vwfs.createVariable('VW_200cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_200cm_FullSun.long_name = 'Volumetric water content under full sun, 200cm'
VW_200cm_FullSun.units = 'm3H2O m-3soil'

## nc_tsoilwell
annee_tsoilwell = nc_tsoilwell.createVariable('year', np.float64, ('year',))
annee_tsoilwell.long_name = 'annee'

doy_tsoilwell = nc_tsoilwell.createVariable('doy', np.float64, ('DOY',))
doy_tsoilwell.long_name = 'Day Of Year / numero du jour dans année (1-365)'

hnum_tsoilwell = nc_tsoilwell.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_tsoilwell.long_name = 'Heure numerique dans la journée'
hnum_tsoilwell.units = 'heures dans la journée'

SoilT_Well2_Shaded_20cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_20cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_20cm.long_name = 'Soil temperature profile under shade, well 2, 20cm'
SoilT_Well2_Shaded_20cm.units = '°C (degré celcius)'

SoilT_Well2_Shaded_40cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_40cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_40cm.long_name = 'Soil temperature profile under shade, well 2, 40cm'
SoilT_Well2_Shaded_40cm.units = 'heures dans la journée'

SoilT_Well2_Shaded_60cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_60cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_60cm.long_name = 'Soil temperature profile under shade, well 2, 60cm'
SoilT_Well2_Shaded_60cm.units = 'heures dans la journée'

SoilT_Well2_Shaded_80cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_80cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_80cm.long_name = 'Soil temperature profile under shade, well 2, 80cm'
SoilT_Well2_Shaded_80cm.units = 'heures dans la journée'

SoilT_Well2_Shaded_120cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_120cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_120cm.long_name = 'Soil temperature profile under shade, well 2, 120cm'
SoilT_Well2_Shaded_120cm.units = 'heures dans la journée'

SoilT_Well2_Shaded_140cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_140cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_140cm.long_name = 'Soil temperature profile under shade, well 2, 140cm'
SoilT_Well2_Shaded_140cm.units = 'heures dans la journée'

SoilT_Well2_Shaded_160cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_160cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_160cm.long_name = 'Soil temperature profile under shade, well 2, 160cm'
SoilT_Well2_Shaded_160cm.units = 'heures dans la journée'

SoilT_Well2_Shaded_180cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_180cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_180cm.long_name = 'Soil temperature profile under shade, well 2, 180cm'
SoilT_Well2_Shaded_180cm.units = 'heures dans la journée'

SoilT_Well2_Shaded_280cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_280cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_280cm.long_name = 'Soil temperature profile under shade, well 2, 280cm'
SoilT_Well2_Shaded_280cm.units = 'heures dans la journée'

SoilT_Well2_Shaded_380cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_380cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_380cm.long_name = 'Soil temperature profile under shade, well 2, 380cm'
SoilT_Well2_Shaded_380cm.units = 'heures dans la journée'

SoilT_Well2_Shaded_480cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_480cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_480cm.long_name = 'Soil temperature profile under shade, well 2, 480cm'
SoilT_Well2_Shaded_480cm.units = 'heures dans la journée'

## nc_vwwell
annee_vwwell = nc_vwwell.createVariable('year', np.float64, ('year',))
annee_vwwell.long_name = 'annee'

doy_vwwell = nc_vwwell.createVariable('doy', np.float64, ('DOY',))
doy_vwwell.long_name = 'Day Of Year / numero du jour dans année (1-365)'

hnum_vwwell = nc_vwwell.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_vwwell.long_name = 'Heure numerique dans la journée'
hnum_vwwell.units = 'heures dans la journée'

SoilVWC_Well2_Shaded_20cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_20cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_20cm.long_name = 'Volumetric water content  under shade, well 2, 20cm'
SoilVWC_Well2_Shaded_20cm.units = 'm3H2O m-3soil'

SoilVWC_Well2_Shaded_40cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_40cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_40cm.long_name = 'Volumetric water content  under shade, well 2, 40cm'
SoilVWC_Well2_Shaded_40cm.units = 'm3H2O m-3soil'

SoilVWC_Well2_Shaded_60cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_60cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_60cm.long_name = 'Volumetric water content  under shade, well 2, 60cm'
SoilVWC_Well2_Shaded_60cm.units = 'm3H2O m-3soil'

SoilVWC_Well2_Shaded_80cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_80cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_80cm.long_name = 'Volumetric water content  under shade, well 2, 80cm'
SoilVWC_Well2_Shaded_80cm.units = 'm3H2O m-3soil'

SoilVWC_Well2_Shaded_120cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_120cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_120cm.long_name = 'Volumetric water content  under shade, well 2, 120cm'
SoilVWC_Well2_Shaded_120cm.units = 'm3H2O m-3soil'

SoilVWC_Well2_Shaded_140cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_140cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_140cm.long_name = 'Teneur en eau volumétrique à 140 cm de profondeur - dans le puit'
SoilVWC_Well2_Shaded_140cm.units = 'm3H2O m-3soil'

SoilVWC_Well2_Shaded_160cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_160cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_160cm.long_name = 'Volumetric water content  under shade, well 2, 160cm'
SoilVWC_Well2_Shaded_160cm.units = 'm3H2O m-3soil'

SoilVWC_Well2_Shaded_180cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_180cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_180cm.long_name = 'Volumetric water content  under shade, well 2, 180cm'
SoilVWC_Well2_Shaded_180cm.units = 'm3H2O m-3soil'

SoilVWC_Well2_Shaded_280cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_280cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_280cm.long_name = 'Volumetric water content  under shade, well 2, 280cm'
SoilVWC_Well2_Shaded_280cm.units = 'm3H2O m-3soil'

SoilVWC_Well2_Shaded_380cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_380cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_380cm.long_name = 'Volumetric water content  under shade, well 2, 380cm'
SoilVWC_Well2_Shaded_380cm.units = 'm3H2O m-3soil'

SoilVWC_Well2_Shaded_480cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_480cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_480cm.long_name = 'Volumetric water content  under shade, well 2, 480cm'
SoilVWC_Well2_Shaded_480cm.units = 'm3H2O m-3soil'

# %% [markdown]
# ### meteo

# %%
# meteo


## nc_msSmallAnt 
annee_msSmallAnt = nc_msSmallAnt.createVariable('year', np.float64, ('year',))
annee_msSmallAnt.long_name = 'annee'

doy_msSmallAnt = nc_msSmallAnt.createVariable('doy', np.float64, ('DOY',))
doy_msSmallAnt.long_name = 'Day Of Year / numero du jour dans année (1-365)'

hnum_msSmallAnt = nc_msSmallAnt.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_msSmallAnt.long_name = 'Heure numerique dans la journée'
hnum_msSmallAnt.units = 'heures dans la journée'

Tair_2m_SmallAnt = nc_msSmallAnt.createVariable('Tair_2m_SmallAnt', np.float64, ('year','DOY','Hournumeric',))
Tair_2m_SmallAnt.long_name = 'temperature air a 2m - Small Antenna'
Tair_2m_SmallAnt.units = '°C'

Rh_2m_SmallAnt = nc_msSmallAnt.createVariable('Delta2m_kPadegC', np.float64, ('year','DOY','Hournumeric',))
Rh_2m_SmallAnt.long_name = 'Humidite relative a 2m - Small Antenna'
Rh_2m_SmallAnt.units = '%'

WS_2m_SmallAntSonic_ms = nc_msSmallAnt.createVariable('WS_2m_SmallAntSonic_ms', np.float64, ('year','DOY','Hournumeric',))
WS_2m_SmallAntSonic_ms.long_name = 'Wind Speed - Small Antenna'
WS_2m_SmallAntSonic_ms.units = 'm/s'

VPD_2m_hPa = nc_msSmallAnt.createVariable('VPD_2m_hPa', np.float64, ('year','DOY','Hournumeric',))
VPD_2m_hPa.long_name = 'déficit de pression de vapeur a 2m'
VPD_2m_hPa.units = 'hPa'

ETo_2m_mmsemih_Gf = nc_msSmallAnt.createVariable('ETo_2m_mmsemih_Gf', np.float64, ('year','DOY','Hournumeric',))
ETo_2m_mmsemih_Gf.long_name = 'P-Monteith Potential Evapotranspiration Eto Allen'
ETo_2m_mmsemih_Gf.units = 'mm/h'

## nc_msTallAnt
annee_msTallAnt = nc_msTallAnt.createVariable('year', np.float64, ('year',))
annee_msTallAnt.long_name = 'annee'

doy_msTallAnt = nc_msTallAnt.createVariable('doy', np.float64, ('DOY',))
doy_msTallAnt.long_name = 'Day Of Year / numero du jour dans année (1-365)'

hnum_msTallAnt = nc_msTallAnt.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_msTallAnt.long_name = 'Heure numerique dans la journée'
hnum_msTallAnt.units = 'heures dans la journée'
            
PARtot_20m_mE = nc_msTallAnt.createVariable('PARtot_20m_mE', np.float64, ('year','DOY','Hournumeric',))
PARtot_20m_mE.long_name = 'PAR total'
PARtot_20m_mE.units = 'micE/m2.s'

NDVI_TallAnt_crop = nc_msTallAnt.createVariable('NDVI_TallAnt_crop', np.float64, ('year','DOY','Hournumeric',))
NDVI_TallAnt_crop.long_name = 'NDVI'

Tair_20m_degC = nc_msTallAnt.createVariable('Tair_20m_degC', np.float64, ('year','DOY','Hournumeric',))
Tair_20m_degC.long_name = 'Air Temperature'
Tair_20m_degC.units = '°C'

Rh_20m_pc = nc_msTallAnt.createVariable('Rh_20m_pc', np.float64, ('year','DOY','Hournumeric',))
Rh_20m_pc.long_name = 'Relative Humidity'
Rh_20m_pc.units = '%'

WindSpeed_20m_ms1 = nc_msTallAnt.createVariable('WindSpeed_20m_ms1', np.float64, ('year','DOY','Hournumeric',))
WindSpeed_20m_ms1.long_name = 'Wind Speed'
WindSpeed_20m_ms1.units = 'm/s'

WindDir_20m_deg = nc_msTallAnt.createVariable('WindDir_20m_deg', np.float64, ('year','DOY','Hournumeric',))
WindDir_20m_deg.long_name = 'Wind Direction'
WindDir_20m_deg.units = 'deg, E = 90'

Rain_mmsemih = nc_msTallAnt.createVariable('Rain_mmsemih', np.float64, ('year','DOY','Hournumeric',))
Rain_mmsemih.long_name = 'Rainfall'
Rain_mmsemih.units = 'mm/30min'

P_20m_hPa = nc_msTallAnt.createVariable('P_20m_hPa', np.float64, ('year','DOY','Hournumeric',))
P_20m_hPa.long_name = 'Atmospheric Pressure'
P_20m_hPa.units = 'hPa'

eVais_20m_hPa = nc_msTallAnt.createVariable('eVais_20m_hPa', np.float64, ('year','DOY','Hournumeric',))
eVais_20m_hPa.long_name = 'vapour pressure'
eVais_20m_hPa.units = 'hPa'

VPD_20m_hPa = nc_msTallAnt.createVariable('VPD_20m_hPa', np.float64, ('year','DOY','Hournumeric',))
VPD_20m_hPa.long_name = 'vapour pressure deficit'
VPD_20m_hPa.units = 'hPa'

PARtot_20m_mE_filt = nc_msTallAnt.createVariable('PARtot_20m_mE_filt', np.float64, ('year','DOY','Hournumeric',))
PARtot_20m_mE_filt.long_name = 'PAR total'
PARtot_20m_mE_filt.units = 'micE/m2.s'

Rg_estim_20m = nc_msTallAnt.createVariable('Rg_estim_20m', np.float64, ('year','DOY','Hournumeric',))
Rg_estim_20m.long_name = 'Estimated global radiation = SW downwards'
Rg_estim_20m.units = 'W/m2'

PARDiff_ModEmpir = nc_msTallAnt.createVariable('PARDiff_ModEmpir', np.float64, ('year','DOY','Hournumeric',))
PARDiff_ModEmpir.long_name = 'Estimated PAR diffuse'
PARDiff_ModEmpir.units = 'micE/m2.s'

Diff_Fraction_ModEmpir = nc_msTallAnt.createVariable('Diff_Fraction_ModEmpir', np.float64, ('year','DOY','Hournumeric',))
Diff_Fraction_ModEmpir.long_name = 'Estimated Diffuse fraction'

IR100_LST_TallAnt_degC = nc_msTallAnt.createVariable('IR100_LST_TallAnt_degC', np.float64, ('year','DOY','Hournumeric',))
IR100_LST_TallAnt_degC.long_name = 'Land Surface Temperature IR100'
IR100_LST_TallAnt_degC.units = '°C'

IR120_LST_TallAnt_degC = nc_msTallAnt.createVariable('IR120_LST_TallAnt_degC', np.float64, ('year','DOY','Hournumeric',))
IR120_LST_TallAnt_degC.long_name = 'Land Surface Temperature IR120'
IR120_LST_TallAnt_degC.units = '°C'

ETo_20m_mmh_Gf = nc_msTallAnt.createVariable('ETo_20m_mmh_Gf', np.float64, ('year','DOY','Hournumeric',))
ETo_20m_mmh_Gf.long_name = 'P-Monteith Potential Evapotranspiration Eto Allen'
ETo_20m_mmh_Gf.units = 'mm/h'

annee_fluxTallAnt = nc_fluxTallAnt.createVariable('year', np.float64, ('year',))
annee_fluxTallAnt.long_name = 'annee'

doy_fluxTallAnt = nc_fluxTallAnt.createVariable('doy', np.float64, ('DOY',))
doy_fluxTallAnt.long_name = 'Day Of Year / numero du jour dans année (1-365)'

hnum_fluxTallAnt = nc_fluxTallAnt.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_fluxTallAnt.long_name = 'Heure numerique dans la journée'
hnum_fluxTallAnt.units = 'heures dans la journée'

NEE_micmolm2s_20m = nc_fluxTallAnt.createVariable('NEE_micmolm2s_20m', np.float64, ('year','DOY','Hournumeric',))
NEE_micmolm2s_20m.long_name = 'Net CO2 Ecosystem Exchange_measured_with gaps_20m'
NEE_micmolm2s_20m.units = 'umolm-2s-1'

LE_Wm2__20m = nc_fluxTallAnt.createVariable('LE_Wm2__20m', np.float64, ('year','DOY','Hournumeric',))
LE_Wm2__20m.long_name = 'Latent heat flux_measured_with gaps_20m'
LE_Wm2__20m.units = 'W/m2'

H_Wm2_20m = nc_fluxTallAnt.createVariable('H_Wm2_20m', np.float64, ('year','DOY','Hournumeric',))
H_Wm2_20m.long_name = 'Sensible heat flux_measured_with gaps_20m'
H_Wm2_20m.units = 'W/m2'

Ustar_Thres_20m = nc_fluxTallAnt.createVariable('Ustar_Thres_20m', np.float64, ('year','DOY','Hournumeric',))
Ustar_Thres_20m.long_name = 'Friction velocity threshold_20m'
Ustar_Thres_20m.units = 'm/s'

Reco_MR_micmolm2s_20m = nc_fluxTallAnt.createVariable('Reco_MR_micmolm2s_20m', np.float64, ('year','DOY','Hournumeric',))
Reco_MR_micmolm2s_20m.long_name = 'Reco_Reichstein 2005 method_20m'
Reco_MR_micmolm2s_20m.units = 'umolm-2s-1'

GPP_MR_micmolm2s_20m = nc_fluxTallAnt.createVariable('GPP_MR_micmolm2s_20m', np.float64, ('year','DOY','Hournumeric',))
GPP_MR_micmolm2s_20m.long_name = 'GPP_Reichstein 2005 method_20m'
GPP_MR_micmolm2s_20m.units = 'umolm-2s-1'

GPP_MR_Gfqc_20m = nc_fluxTallAnt.createVariable('GPP_MR_Gfqc_20m', np.float64, ('year','DOY','Hournumeric',))
GPP_MR_Gfqc_20m.long_name = 'GPP_Reichstein 2005 method_20m_quality check'

Reco_DT_micmolm2s_20m = nc_fluxTallAnt.createVariable('Reco_DT_micmolm2s_20m', np.float64, ('year','DOY','Hournumeric',))
Reco_DT_micmolm2s_20m.long_name = 'Reco_20m, Lasslop 2010 method, Gf'
Reco_DT_micmolm2s_20m.units = 'umolm-2s-1'

GPP_DT_micmolm2s_20m = nc_fluxTallAnt.createVariable('GPP_DT_micmolm2s_20m', np.float64, ('year','DOY','Hournumeric',))
GPP_DT_micmolm2s_20m.long_name = 'GPP_20m, Lasslop 2010 method, Gf'
GPP_DT_micmolm2s_20m.units = 'umolm-2s-1'

GPP_DT_uStar_SD_micmolm2s_20m = nc_fluxTallAnt.createVariable('GPP_DT_uStar_SD_micmolm2s_20m', np.float64, ('year','DOY','Hournumeric',))
GPP_DT_uStar_SD_micmolm2s_20m.long_name = 'GPP_20m, SD Lasslop 2010 method, Gf'
GPP_DT_uStar_SD_micmolm2s_20m.units = 'umolm-2s-1'

LE_Gf_Wm2_20m = nc_fluxTallAnt.createVariable('LE_Gf_Wm2_20m', np.float64, ('year','DOY','Hournumeric',))
LE_Gf_Wm2_20m.long_name = 'Latent heat flux_measured_Gf_20m'
LE_Gf_Wm2_20m.units = 'Wm-2'

LE_Gfqc_20m = nc_fluxTallAnt.createVariable('LE_Gfqc_20m', np.float64, ('year','DOY','Hournumeric',))
LE_Gfqc_20m.long_name = 'Latent heat flux_measured_quality check_20m'

H_Gf_20m = nc_fluxTallAnt.createVariable('H_Gf_20m', np.float64, ('year','DOY','Hournumeric',))
H_Gf_20m.long_name = 'Sensible heat flux_measured_Gf_20m'
H_Gf_20m.units = 'Wm-2'

H_Gfqc_20m = nc_fluxTallAnt.createVariable('H_Gfqc_20m', np.float64, ('year','DOY','Hournumeric',))
H_Gfqc_20m.long_name = 'Sensible heat flux_measured_quality check_20m'

# %% [markdown]
# ### tree

# %%
#tree
##nc_LaicwAntPlotScale
annee_LaicwAntPlotScale = nc_LaicwAntPlotScale.createVariable('year', np.float64, ('year',))
annee_LaicwAntPlotScale.long_name = 'annee'

doy_LaicwAntPlotScale = nc_LaicwAntPlotScale.createVariable('doy', np.float64, ('DOY',))
doy_LaicwAntPlotScale.long_name = 'Day Of Year / numero du jour dans année (1-365)'

hnum_LaicwAntPlotScale = nc_LaicwAntPlotScale.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_LaicwAntPlotScale.long_name = 'Heure numerique dans la journée'
hnum_LaicwAntPlotScale.units = 'heures dans la journée'

CropWeedLAI = nc_LaicwAntPlotScale.createVariable('CropWeedLAI', np.float64, ('year','DOY','Hournumeric',))
CropWeedLAI.long_name = 'Cultures + Mauvaises herbes Indice de surface foliaire à l\'échelle de la parcelle en plein soleil'
CropWeedLAI.units = 'm2leaf m-2soil'

##nc_LaiTreecwAntPlotScale
annee_LaiTreecwAntPlotScale = nc_LaiTreecwAntPlotScale.createVariable('year', np.float64, ('year',))
annee_LaiTreecwAntPlotScale.long_name = 'annee'

doy_LaiTreecwAntPlotScale = nc_LaiTreecwAntPlotScale.createVariable('doy', np.float64, ('DOY',))
doy_LaiTreecwAntPlotScale.long_name = 'Day Of Year / numero du jour dans année (1-365)'

hnum_LaiTreecwAntPlotScale = nc_LaiTreecwAntPlotScale.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_LaiTreecwAntPlotScale.long_name = 'Heure numerique dans la journée'
hnum_LaiTreecwAntPlotScale.units = 'heures dans la journée'

TreeandCropWeedLAI = nc_LaiTreecwAntPlotScale.createVariable('TreeandCropWeedLAI', np.float64, ('year','DOY','Hournumeric',))
TreeandCropWeedLAI.long_name = 'Indice de surface foliaire des arbres+cultures+mauvaises herbes à l\'échelle de la parcelle'
TreeandCropWeedLAI.units = 'm2leaf m-2soil'

##nc_netRadiation
annee_netRadiation = nc_netRadiation.createVariable('year', np.float64, ('year',))
annee_netRadiation.long_name = 'annee'

doy_netRadiation = nc_netRadiation.createVariable('doy', np.float64, ('DOY',))
doy_netRadiation.long_name = 'Day Of Year / numero du jour dans année (1-365)'

hnum_netRadiation = nc_netRadiation.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_netRadiation.long_name = 'Heure numerique dans la journée'
hnum_netRadiation.units = 'heures dans la journée'

Rn_20m_Wm2 = nc_netRadiation.createVariable('Rn_20m_Wm2', np.float64, ('year','DOY','Hournumeric',))
Rn_20m_Wm2.long_name = 'Net Radiation'
Rn_20m_Wm2.units = 'W/m²'

Rn_20m_Wm2_gf = nc_netRadiation.createVariable('Rn_20m_Wm2_gf', np.float64, ('year','DOY','Hournumeric',))
Rn_20m_Wm2_gf.long_name = 'Net Radiation gap filled'
Rn_20m_Wm2_gf.units = 'W/m²'

Rn_20m_Wm2_Lagouarde_gf = nc_netRadiation.createVariable('Rn_20m_Wm2_Lagouarde_gf', np.float64, ('year','DOY','Hournumeric',))
Rn_20m_Wm2_Lagouarde_gf.long_name = 'Net Radiation Lagouarde gap filled'
Rn_20m_Wm2_Lagouarde_gf.units = 'W/m²'



## nc_percentMLS
annee_percentMLS = nc_leafRate.createVariable('year', np.float64, ('year',))
annee_percentMLS.long_name = 'annee'

doy_percentMLS = nc_leafRate.createVariable('doy', np.float64, ('DOY',))
doy_percentMLS.long_name = 'Day Of Year / numero du jour dans année (1-365)'

hnum_percentMLS = nc_leafRate.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_percentMLS.long_name = 'Heure numerique dans la journée'
hnum_percentMLS.units = 'heures dans la journée'

Leaf_Fa_1_pc = nc_leafRate.createVariable('Leaf_Fa_1_pc', np.float64, ('year','DOY','Hournumeric',))
Leaf_Fa_1_pc.long_name = 'Rate of maximum lefing stage - Faidherbia 1'
Leaf_Fa_1_pc.units = '%'

Leaf_Fa_2_pc = nc_leafRate.createVariable('Leaf_Fa_2_pc', np.float64, ('year','DOY','Hournumeric',))
Leaf_Fa_2_pc.long_name = 'Rate of maximum lefing stage - Faidherbia 2'
Leaf_Fa_2_pc.units = '%'

Leaf_Fa_3_pc = nc_leafRate.createVariable('Leaf_Fa_3_pc', np.float64, ('year','DOY','Hournumeric',))
Leaf_Fa_3_pc.long_name = 'Pourcentage du stade de départ maximal - Faidherbia 3'
Leaf_Fa_3_pc.units = '%'

Leaf_Fa_4_pc = nc_leafRate.createVariable('Leaf_Fa_4_pc', np.float64, ('year','DOY','Hournumeric',))
Leaf_Fa_4_pc.long_name = 'Pourcentage du stade de départ maximal - Faidherbia 4'
Leaf_Fa_4_pc.units = '%'

Leaf_Fa_5_pc = nc_leafRate.createVariable('Leaf_Fa_5_pc', np.float64, ('year','DOY','Hournumeric',))
Leaf_Fa_5_pc.long_name = 'Pourcentage du stade de départ maximal - Faidherbia 5'
Leaf_Fa_5_pc.units = '%'

Leaf_Fa_6_pc = nc_leafRate.createVariable('Leaf_Fa_6_pc', np.float64, ('year','DOY','Hournumeric',))
Leaf_Fa_6_pc.long_name = 'Pourcentage du stade de départ maximal - Faidherbia 6'
Leaf_Fa_6_pc.units = '%'

Leaf_Fa_7_pc = nc_leafRate.createVariable('Leaf_Fa_7_pc', np.float64, ('year','DOY','Hournumeric',))
Leaf_Fa_7_pc.long_name = 'Pourcentage du stade de départ maximal - Faidherbia 7'
Leaf_Fa_7_pc.units = '%'

Leaf_Fa_8_pc = nc_leafRate.createVariable('Leaf_Fa_8_pc', np.float64, ('year','DOY','Hournumeric',))
Leaf_Fa_8_pc.long_name = 'Pourcentage du stade de départ maximal - Faidherbia 8'
Leaf_Fa_8_pc.units = '%'

Leaf_Fa_9_pc = nc_leafRate.createVariable('Leaf_Fa_9_pc', np.float64, ('year','DOY','Hournumeric',))
Leaf_Fa_9_pc.long_name = 'Pourcentage du stade de départ maximal - Faidherbia 9'
Leaf_Fa_9_pc.units = '%'

Leaf_Fa_10_pc = nc_leafRate.createVariable('Leaf_Fa_10_pc', np.float64, ('year','DOY','Hournumeric',))
Leaf_Fa_10_pc.long_name = 'Pourcentage du stade de départ maximal - Faidherbia 10'
Leaf_Fa_10_pc.units = '%'

Leaf_Fa_11_pc = nc_leafRate.createVariable('Leaf_Fa_11_pc', np.float64, ('year','DOY','Hournumeric',))
Leaf_Fa_11_pc.long_name = 'Pourcentage du stade de départ maximal - Faidherbia 11'
Leaf_Fa_11_pc.units = '%'

Leaf_Fa_12_pc = nc_leafRate.createVariable('Leaf_Fa_12_pc', np.float64, ('year','DOY','Hournumeric',))
Leaf_Fa_12_pc.long_name = 'Pourcentage du stade de départ maximal - Faidherbia 12'
Leaf_Fa_12_pc.units = '%'

Leaf_Fa_27_pc = nc_leafRate.createVariable('Leaf_Fa_27_pc', np.float64, ('year','DOY','Hournumeric',))
Leaf_Fa_27_pc.long_name = 'Pourcentage du stade de départ maximal - Faidherbia 27'
Leaf_Fa_27_pc.units = '%'

Leaf_Fa_28_pc = nc_leafRate.createVariable('Leaf_Fa_28_pc', np.float64, ('year','DOY','Hournumeric',))
Leaf_Fa_28_pc.long_name = 'Pourcentage du stade de départ maximal - Faidherbia 28'
Leaf_Fa_28_pc.units = '%'

Leaf_Fa_46_pc = nc_leafRate.createVariable('Leaf_Fa_46_pc', np.float64, ('year','DOY','Hournumeric',))
Leaf_Fa_46_pc.long_name = 'Pourcentage du stade de départ maximal - Faidherbia 46'
Leaf_Fa_46_pc.units = '%'

## nc_leafAD
annee_leafAD = nc_leafAD.createVariable('year', np.float64, ('year',))
annee_leafAD.long_name = 'annee'

doy_leafAD = nc_leafAD.createVariable('doy', np.float64, ('DOY',))
doy_leafAD.long_name = 'Day Of Year / numero du jour dans année (1-365)'

hnum_leafAD = nc_leafAD.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_leafAD.long_name = 'Heure numerique dans la journée'
hnum_leafAD.units = 'heures dans la journée'

LAD_Fa_1 = nc_leafAD.createVariable('LAD_Fa_1', np.float64, ('year','DOY','Hournumeric',))
LAD_Fa_1.long_name = 'Densité de la surface foliaire - Faidherbia 1'
LAD_Fa_1.units = 'm2leaf m3crown-1'

LAD_Fa_2 = nc_leafAD.createVariable('LAD_Fa_2', np.float64, ('year','DOY','Hournumeric',))
LAD_Fa_2.long_name = 'Densité de la surface foliaire - Faidherbia 2'
LAD_Fa_2.units = 'm2leaf m3crown-1'

LAD_Fa_3 = nc_leafAD.createVariable('LAD_Fa_3', np.float64, ('year','DOY','Hournumeric',))
LAD_Fa_3.long_name = 'Densité de la surface foliaire - Faidherbia 3'
LAD_Fa_3.units = 'm2leaf m3crown-1'

LAD_Fa_4 = nc_leafAD.createVariable('LAD_Fa_4', np.float64, ('year','DOY','Hournumeric',))
LAD_Fa_4.long_name = 'Densité de la surface foliaire - Faidherbia 4'
LAD_Fa_4.units = 'm2leaf m3crown-1'

LAD_Fa_5 = nc_leafAD.createVariable('LAD_Fa_5', np.float64, ('year','DOY','Hournumeric',))
LAD_Fa_5.long_name = 'Densité de la surface foliaire - Faidherbia 5'
LAD_Fa_5.units = 'm2leaf m3crown-1'

LAD_Fa_6 = nc_leafAD.createVariable('LAD_Fa_6', np.float64, ('year','DOY','Hournumeric',))
LAD_Fa_6.long_name = 'Densité de la surface foliaire - Faidherbia 6'
LAD_Fa_6.units = 'm2leaf m3crown-1'

LAD_Fa_7 = nc_leafAD.createVariable('LAD_Fa_7', np.float64, ('year','DOY','Hournumeric',))
LAD_Fa_7.long_name = 'Densité de la surface foliaire - Faidherbia 7'
LAD_Fa_7.units = 'm2leaf m3crown-1'

LAD_Fa_8 = nc_leafAD.createVariable('LAD_Fa_8', np.float64, ('year','DOY','Hournumeric',))
LAD_Fa_8.long_name = 'Densité de la surface foliaire - Faidherbia 8'
LAD_Fa_8.units = 'm2leaf m3crown-1'

LAD_Fa_9 = nc_leafAD.createVariable('LAD_Fa_9', np.float64, ('year','DOY','Hournumeric',))
LAD_Fa_9.long_name = 'Densité de la surface foliaire - Faidherbia 9'
LAD_Fa_9.units = 'm2leaf m3crown-1'

LAD_Fa_10 = nc_leafAD.createVariable('LAD_Fa_10', np.float64, ('year','DOY','Hournumeric',))
LAD_Fa_10.long_name = 'Densité de la surface foliaire - Faidherbia 10'
LAD_Fa_10.units = 'm2leaf m3crown-1'

LAD_Fa_11 = nc_leafAD.createVariable('LAD_Fa_11', np.float64, ('year','DOY','Hournumeric',))
LAD_Fa_11.long_name = 'Densité de la surface foliaire - Faidherbia 11'
LAD_Fa_11.units = 'm2leaf m3crown-1'

LAD_Fa_12 = nc_leafAD.createVariable('LAD_Fa_12', np.float64, ('year','DOY','Hournumeric',))
LAD_Fa_12.long_name = 'Densité de la surface foliaire - Faidherbia 12'
LAD_Fa_12.units = 'm2leaf m3crown-1'

LAD_Fa_27 = nc_leafAD.createVariable('LAD_Fa_27', np.float64, ('year','DOY','Hournumeric',))
LAD_Fa_27.long_name = 'Densité de la surface foliaire - Faidherbia 27'
LAD_Fa_27.units = 'm2leaf m3crown-1'

LAD_Fa_28 = nc_leafAD.createVariable('LAD_Fa_28', np.float64, ('year','DOY','Hournumeric',))
LAD_Fa_28.long_name = 'Densité de la surface foliaire - Faidherbia 28'
LAD_Fa_28.units = 'm2leaf m3crown-1'

LAD_Fa_46 = nc_leafAD.createVariable('LAD_Fa_46', np.float64, ('year','DOY','Hournumeric',))
LAD_Fa_46.long_name = 'Densité de la surface foliaire - Faidherbia 46'
LAD_Fa_46.units = 'm2leaf m3crown-1'

## nc_leafAPT

annee_leafAPT = nc_leafAPT.createVariable('year', np.float64, ('year',))
annee_leafAPT.long_name = 'annee'

doy_leafAPT = nc_leafAPT.createVariable('doy', np.float64, ('DOY',))
doy_leafAPT.long_name = 'Day Of Year / numero du jour dans année (1-365)'

hnum_leafAPT = nc_leafAPT.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_leafAPT.long_name = 'Heure numerique dans la journée'
hnum_leafAPT.units = 'heures dans la journée'

LA_Fa_1 = nc_leafAPT.createVariable('LA_Fa_1', np.float64, ('year','DOY','Hournumeric',))
LA_Fa_1.long_name = 'Surface foliaire par arbre - Faidherbia 1'
LA_Fa_1.units = 'm2leaf Tree-1'

LA_Fa_2 = nc_leafAPT.createVariable('LA_Fa_2', np.float64, ('year','DOY','Hournumeric',))
LA_Fa_2.long_name = 'Surface foliaire par arbre - Faidherbia 2'
LA_Fa_2.units = 'm2leaf Tree-1'

LA_Fa_3 = nc_leafAPT.createVariable('LA_Fa_3', np.float64, ('year','DOY','Hournumeric',))
LA_Fa_3.long_name = 'Surface foliaire par arbre - Faidherbia 3'
LA_Fa_3.units = 'm2leaf Tree-1'

LA_Fa_4 = nc_leafAPT.createVariable('LA_Fa_4', np.float64, ('year','DOY','Hournumeric',))
LA_Fa_4.long_name = 'Surface foliaire par arbre - Faidherbia 4'
LA_Fa_4.units = 'm2leaf Tree-1'

LA_Fa_5 = nc_leafAPT.createVariable('LA_Fa_5', np.float64, ('year','DOY','Hournumeric',))
LA_Fa_5.long_name = 'Surface foliaire par arbre - Faidherbia 5'
LA_Fa_5.units = 'm2leaf Tree-1'

LA_Fa_6 = nc_leafAPT.createVariable('LA_Fa_6', np.float64, ('year','DOY','Hournumeric',))
LA_Fa_6.long_name = 'Surface foliaire par arbre - Faidherbia 6'
LA_Fa_6.units = 'm2leaf Tree-1'

LA_Fa_7 = nc_leafAPT.createVariable('LA_Fa_7', np.float64, ('year','DOY','Hournumeric',))
LA_Fa_7.long_name = 'Surface foliaire par arbre - Faidherbia 7'
LA_Fa_7.units = 'm2leaf Tree-1'

LA_Fa_8 = nc_leafAPT.createVariable('LA_Fa_8', np.float64, ('year','DOY','Hournumeric',))
LA_Fa_8.long_name = 'Surface foliaire par arbre - Faidherbia 8'
LA_Fa_8.units = 'm2leaf Tree-1'

LA_Fa_9 = nc_leafAPT.createVariable('LA_Fa_9', np.float64, ('year','DOY','Hournumeric',))
LA_Fa_9.long_name = 'Surface foliaire par arbre - Faidherbia 9'
LA_Fa_9.units = 'm2leaf Tree-1'

LA_Fa_10 = nc_leafAPT.createVariable('LA_Fa_10', np.float64, ('year','DOY','Hournumeric',))
LA_Fa_10.long_name = 'Surface foliaire par arbre - Faidherbia 10'
LA_Fa_10.units = 'm2leaf Tree-1'

LA_Fa_11 = nc_leafAPT.createVariable('LA_Fa_11', np.float64, ('year','DOY','Hournumeric',))
LA_Fa_11.long_name = 'Surface foliaire par arbre - Faidherbia 11'
LA_Fa_11.units = 'm2leaf Tree-1'

LA_Fa_12 = nc_leafAPT.createVariable('LA_Fa_12', np.float64, ('year','DOY','Hournumeric',))
LA_Fa_12.long_name = 'Surface foliaire par arbre - Faidherbia 12'
LA_Fa_12.units = 'm2leaf Tree-1'

LA_Fa_27 = nc_leafAPT.createVariable('LA_Fa_27', np.float64, ('year','DOY','Hournumeric',))
LA_Fa_27.long_name = 'Surface foliaire par arbre - Faidherbia 27'
LA_Fa_27.units = 'm2leaf Tree-1'

LA_Fa_28 = nc_leafAPT.createVariable('LA_Fa_28', np.float64, ('year','DOY','Hournumeric',))
LA_Fa_28.long_name = 'Surface foliaire par arbre - Faidherbia 28'
LA_Fa_28.units = 'm2leaf Tree-1'

LA_Fa_46 = nc_leafAPT.createVariable('LA_Fa_46', np.float64, ('year','DOY','Hournumeric',))
LA_Fa_46.long_name = 'Surface foliaire par arbre - Faidherbia 46'
LA_Fa_46.units = 'm2leaf Tree-1'

## nc_dripLLAI
annee_dripLLAI = nc_dripLLAI.createVariable('year', np.float64, ('year',))
annee_dripLLAI.long_name = 'annee'

doy_dripLLAI = nc_dripLLAI.createVariable('doy', np.float64, ('DOY',))
doy_dripLLAI.long_name = 'Day Of Year / numero du jour dans année (1-365)'

hnum_dripLLAI = nc_dripLLAI.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_dripLLAI.long_name = 'Heure numerique dans la journée'
hnum_dripLLAI.units = 'heures dans la journée'

DripLineLAI_Fa_1 = nc_dripLLAI.createVariable('DripLineLAI_Fa_1', np.float64, ('year','DOY','Hournumeric',))
DripLineLAI_Fa_1.long_name = 'Indice de surface foliaire de la ligne d\'égouttement - Faidherbia 1'
DripLineLAI_Fa_1.units = 'm2leaf m-2soildriplinearea'

DripLineLAI_Fa_2 = nc_dripLLAI.createVariable('DripLineLAI_Fa_2', np.float64, ('year','DOY','Hournumeric',))
DripLineLAI_Fa_2.long_name = 'Indice de surface foliaire de la ligne d\'égouttement - Faidherbia 2'
DripLineLAI_Fa_2.units = 'm2leaf m-2soildriplinearea'

DripLineLAI_Fa_3 = nc_dripLLAI.createVariable('DripLineLAI_Fa_3', np.float64, ('year','DOY','Hournumeric',))
DripLineLAI_Fa_3.long_name = 'Indice de surface foliaire de la ligne d\'égouttement - Faidherbia 3'
DripLineLAI_Fa_3.units = 'm2leaf m-2soildriplinearea'

DripLineLAI_Fa_4 = nc_dripLLAI.createVariable('DripLineLAI_Fa_4', np.float64, ('year','DOY','Hournumeric',))
DripLineLAI_Fa_4.long_name = 'Indice de surface foliaire de la ligne d\'égouttement - Faidherbia 4'
DripLineLAI_Fa_4.units = 'm2leaf m-2soildriplinearea'

DripLineLAI_Fa_5 = nc_dripLLAI.createVariable('DripLineLAI_Fa_5', np.float64, ('year','DOY','Hournumeric',))
DripLineLAI_Fa_5.long_name = 'Indice de surface foliaire de la ligne d\'égouttement - Faidherbia 5'
DripLineLAI_Fa_5.units = 'm2leaf m-2soildriplinearea'

DripLineLAI_Fa_6 = nc_dripLLAI.createVariable('DripLineLAI_Fa_6', np.float64, ('year','DOY','Hournumeric',))
DripLineLAI_Fa_6.long_name = 'Indice de surface foliaire de la ligne d\'égouttement - Faidherbia 6'
DripLineLAI_Fa_6.units = 'm2leaf m-2soildriplinearea'

DripLineLAI_Fa_7 = nc_dripLLAI.createVariable('DripLineLAI_Fa_7', np.float64, ('year','DOY','Hournumeric',))
DripLineLAI_Fa_7.long_name = 'Indice de surface foliaire de la ligne d\'égouttement - Faidherbia 7'
DripLineLAI_Fa_7.units = 'm2leaf m-2soildriplinearea'

DripLineLAI_Fa_8 = nc_dripLLAI.createVariable('DripLineLAI_Fa_8', np.float64, ('year','DOY','Hournumeric',))
DripLineLAI_Fa_8.long_name = 'Indice de surface foliaire de la ligne d\'égouttement - Faidherbia 8'
DripLineLAI_Fa_8.units = 'm2leaf m-2soildriplinearea'

DripLineLAI_Fa_9 = nc_dripLLAI.createVariable('DripLineLAI_Fa_9', np.float64, ('year','DOY','Hournumeric',))
DripLineLAI_Fa_9.long_name = 'Indice de surface foliaire de la ligne d\'égouttement - Faidherbia 9'
DripLineLAI_Fa_9.units = 'm2leaf m-2soildriplinearea'

DripLineLAI_Fa_10 = nc_dripLLAI.createVariable('DripLineLAI_Fa_10', np.float64, ('year','DOY','Hournumeric',))
DripLineLAI_Fa_10.long_name = 'Indice de surface foliaire de la ligne d\'égouttement - Faidherbia 10'
DripLineLAI_Fa_10.units = 'm2leaf m-2soildriplinearea'

DripLineLAI_Fa_11 = nc_dripLLAI.createVariable('DripLineLAI_Fa_11', np.float64, ('year','DOY','Hournumeric',))
DripLineLAI_Fa_11.long_name = 'Indice de surface foliaire de la ligne d\'égouttement - Faidherbia 11'
DripLineLAI_Fa_11.units = 'm2leaf m-2soildriplinearea'

DripLineLAI_Fa_12 = nc_dripLLAI.createVariable('DripLineLAI_Fa_12', np.float64, ('year','DOY','Hournumeric',))
DripLineLAI_Fa_12.long_name = 'Indice de surface foliaire de la ligne d\'égouttement - Faidherbia 12'
DripLineLAI_Fa_12.units = 'm2leaf m-2soildriplinearea'

DripLineLAI_Fa_27 = nc_dripLLAI.createVariable('DripLineLAI_Fa_27', np.float64, ('year','DOY','Hournumeric',))
DripLineLAI_Fa_27.long_name = 'Indice de surface foliaire de la ligne d\'égouttement - Faidherbia 27'
DripLineLAI_Fa_27.units = 'm2leaf m-2soildriplinearea'

DripLineLAI_Fa_28 = nc_dripLLAI.createVariable('DripLineLAI_Fa_28', np.float64, ('year','DOY','Hournumeric',))
DripLineLAI_Fa_28.long_name = 'Indice de surface foliaire de la ligne d\'égouttement - Faidherbia 28'
DripLineLAI_Fa_28.units = 'm2leaf m-2soildriplinearea'

DripLineLAI_Fa_46 = nc_dripLLAI.createVariable('DripLineLAI_Fa_46', np.float64, ('year','DOY','Hournumeric',))
DripLineLAI_Fa_46.long_name = 'Indice de surface foliaire de la ligne d\'égouttement - Faidherbia 46'
DripLineLAI_Fa_46.units = 'm2leaf m-2soildriplinearea'

Mean_Tree_LAI_Towerplot = nc_dripLLAI.createVariable('Mean_Tree_LAI_Towerplot', np.float64, ('year','DOY','Hournumeric',))
Mean_Tree_LAI_Towerplot.long_name = 'Indice de surface foliaire des arbres à l\'échelle de la parcelle'
Mean_Tree_LAI_Towerplot.units = 'm2leaf m-2soil'

## nc_TreeCWLAI
annee_TreeCWLAI = nc_CWNDVI.createVariable('year', np.float64, ('year',))
annee_TreeCWLAI.long_name = 'annee'

doy_TreeCWLAI = nc_CWNDVI.createVariable('doy', np.float64, ('DOY',))
doy_TreeCWLAI.long_name = 'Day Of Year / numero du jour dans année (1-365)'

hnum_TreeCWLAI = nc_CWNDVI.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_TreeCWLAI.long_name = 'Heure numerique dans la journée'
hnum_TreeCWLAI.units = 'heures dans la journée'

CropWeedNDVI = nc_CWNDVI.createVariable('CropWeedNDVI', np.float64, ('year','DOY','Hournumeric',))
CropWeedNDVI.long_name = 'Cultures + mauvaises herbes NDVI dans des conditions de plein soleil'

## nc_woodW 

annee_woodW = nc_woodW.createVariable('year', np.float64, ('year',))
annee_woodW.long_name = 'annee'

doy_woodW = nc_woodW.createVariable('doy', np.float64, ('DOY',))
doy_woodW.long_name = 'Day Of Year / numero du jour dans année (1-365)'

hnum_woodW = nc_woodW.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_woodW.long_name = 'Heure numerique dans la journée'
hnum_woodW.units = 'heures dans la journée'

WoodVWC_1 = nc_woodW.createVariable('WoodVWC_1', np.float64, ('year','DOY','Hournumeric',))
WoodVWC_1.long_name = 'Teneur en eau du bois 1'
WoodVWC_1.units = '%'

WoodVWC_2 = nc_woodW.createVariable('WoodVWC_2', np.float64, ('year','DOY','Hournumeric',))
WoodVWC_2.long_name = 'Teneur en eau du bois 2'
WoodVWC_2.units = '%'

WoodT_1 = nc_woodW.createVariable('WoodT_1', np.float64, ('year','DOY','Hournumeric',))
WoodT_1.long_name = 'Température du bois 1'
WoodT_1.units = '°C'

WoodT_2 = nc_woodW.createVariable('WoodT_2', np.float64, ('year','DOY','Hournumeric',))
WoodT_2.long_name = 'Température du bois 2'
WoodT_2.units = '°C'

# %% [markdown]
# ## ecriture des données

# %%
def getData365(data, colonne, jdan=365):
    val = data[colonne]
    return np.array(val).reshape(1,365,48)

# %%
## nc_msSmallAnt 
annee = df_msSmallAnt['Year'].unique()
doy = df_msSmallAnt['DOY'].unique()
hnum = df_msSmallAnt['Hournumeric'].unique()

# %% [markdown]
# ## soil moist

# %%
# soil moist
## nc_tsoilfs

#annee_tsoilfs = nc_tsoilfs.createVariable('year', np.float64, ('year',))
annee_tsoilfs[:] = annee

#doy_tsoilfs = nc_tsoilfs.createVariable('doy', np.float64, ('DOY',))
doy_tsoilfs[:] = doy

#hnum_tsoilfs = nc_tsoilfs.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_tsoilfs[:] = hnum

#Tsoil_0cm_FullSun = nc_tsoilfs.createVariable('Tsoil_0cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
Tsoil_0cm_FullSun[:,:,:] = getData365(df_tsoilfs, 'Tsoil_0cm_FullSun', jdan=365)

#TSoil_2cm_FullSun = nc_tsoilfs.createVariable('TSoil_2cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
TSoil_2cm_FullSun[:,:,:] = getData365(df_tsoilfs, 'TSoil_2cm_FullSun_Tall.Antenna_degC', jdan=365)

#TSoil_5cm_FullSun = nc_tsoilfs.createVariable('TSoil_5cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
TSoil_5cm_FullSun[:,:,:] = getData365(df_tsoilfs, 'TSoil_5cm_FullSun_Tall.Antenna_degC', jdan=365)

#TSoil_15cm_FullSun = nc_tsoilfs.createVariable('TSoil_15cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
TSoil_15cm_FullSun[:,:,:] = getData365(df_tsoilfs, 'TSoil_15cm_FullSun_Tall.Antenna_degC', jdan=365)

#TSoil_30cm_FullSun = nc_tsoilfs.createVariable('TSoil_30cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
TSoil_30cm_FullSun[:,:,:] = getData365(df_tsoilfs, 'TSoil_30cm_FullSun_Tall.Antenna_degC', jdan=365)

#TSoil_60cm_FullSun = nc_tsoilfs.createVariable('TSoil_60cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
TSoil_60cm_FullSun[:,:,:] = getData365(df_tsoilfs, 'TSoil_60cm_FullSun_Tall.Antenna_degC', jdan=365)

#TSoil_100cm_FullSun = nc_tsoilfs.createVariable('TSoil_100cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
TSoil_100cm_FullSun[:,:,:] = getData365(df_tsoilfs, 'TSoil_100cm_FullSun_Tall.Antenna_degC', jdan=365)

#TSoil_150cm_FullSun = nc_tsoilfs.createVariable('TSoil_150cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
TSoil_150cm_FullSun[:,:,:] = getData365(df_tsoilfs, 'TSoil_150cm_FullSun_Tall.Antenna_degC', jdan=365)

#Tsoil_200A_FullSun = nc_tsoilfs.createVariable('Tsoil_200A_FullSun', np.float64, ('year','DOY','Hournumeric',))
Tsoil_200A_FullSun[:,:,:] = getData365(df_tsoilfs, 'Tsoil_200A_FullSun_Tall.Antenna_degC', jdan=365)

## nc_vwfs
       
#annee_vwfs = nc_vwfs.createVariable('year', np.float64, ('year',))
annee_vwfs[:] = annee

#doy_vwfs = nc_vwfs.createVariable('doy', np.float64, ('DOY',))
doy_vwfs[:] = doy

#hnum_vwfs = nc_vwfs.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_vwfs[:] = hnum

#VW_15cm_FullSun = nc_vwfs.createVariable('VW_15cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_15cm_FullSun[:,:,:] = getData365(df_vwfs, 'VW_15cm_FullSun_Tall.Antenna_fractCal', jdan=365)

#VW_30cm_FullSun = nc_vwfs.createVariable('VW_30cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_30cm_FullSun[:,:,:] = getData365(df_vwfs, 'VW_30cm_FullSun_Tall.Antenna_fractCal', jdan=365)

#VW_50cm_FullSun = nc_vwfs.createVariable('VW_50cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_50cm_FullSun[:,:,:] = getData365(df_vwfs, 'VW_50cm_FullSun_Tall.Antenna_fractCal', jdan=365)

#VW_75cm_FullSun = nc_vwfs.createVariable('VW_75cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_75cm_FullSun[:,:,:] = getData365(df_vwfs, 'VW_75cm_FullSun_Tall.Antenna_fractCal', jdan=365)

#VW_100cm_FullSun = nc_vwfs.createVariable('VW_100cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_100cm_FullSun[:,:,:] = getData365(df_vwfs, 'VW_100cm_FullSun_Tall.Antenna_fractCal', jdan=365)

#VW_125cm_FullSun = nc_vwfs.createVariable('VW_125cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_125cm_FullSun[:,:,:] = getData365(df_vwfs, 'VW_125cm_FullSun_Tall.Antenna_fractCal', jdan=365)

#VW_150cm_FullSun = nc_vwfs.createVariable('VW_150cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_150cm_FullSun[:,:,:] = getData365(df_vwfs, 'VW_150cm_FullSun_Tall.Antenna_fractCal', jdan=365)

#VW_175cm_FullSun = nc_vwfs.createVariable('VW_175cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_175cm_FullSun[:,:,:] = getData365(df_vwfs, 'VW_175cm_FullSun_Tall.Antenna_fractCal', jdan=365)

#VW_200cm_FullSun = nc_vwfs.createVariable('VW_200cm_FullSun', np.float64, ('year','DOY','Hournumeric',))
VW_200cm_FullSun[:,:,:] = getData365(df_vwfs, 'VW_200cm_FullSun_Tall.Antenna_fractCal', jdan=365)

## nc_tsoilwell

#annee_tsoilwell = nc_tsoilwell.createVariable('year', np.float64, ('year',))
annee_tsoilwell[:] = annee

#doy_tsoilwell = nc_tsoilwell.createVariable('doy', np.float64, ('DOY',))
doy_tsoilwell[:] = doy

#hnum_tsoilwell = nc_tsoilwell.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_tsoilwell[:] = hnum

#SoilT_Well2_Shaded_20cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_20cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_20cm[:,:,:] = getData365(df_tsoilwell, 'SoilT_Well2_Shaded_20cm_degC', jdan=365)

#SoilT_Well2_Shaded_40cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_40cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_40cm[:,:,:] = getData365(df_tsoilwell, 'SoilT_Well2_Shaded_40cm_degC', jdan=365)

#SoilT_Well2_Shaded_60cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_60cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_60cm[:,:,:] = getData365(df_tsoilwell, 'SoilT_Well2_Shaded_60cm_degC', jdan=365)

#SoilT_Well2_Shaded_80cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_80cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_80cm[:,:,:] = getData365(df_tsoilwell, 'SoilT_Well2_Shaded_80cm_degC', jdan=365)

#SoilT_Well2_Shaded_120cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_120cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_120cm[:,:,:] = getData365(df_tsoilwell, 'SoilT_Well2_Shaded_120cm_degC', jdan=365)

#SoilT_Well2_Shaded_140cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_140cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_140cm[:,:,:] = getData365(df_tsoilwell, 'SoilT_Well2_Shaded_140cm_degC', jdan=365)

#SoilT_Well2_Shaded_160cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_160cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_160cm[:,:,:] = getData365(df_tsoilwell, 'SoilT_Well2_Shaded_160cm_degC', jdan=365)

#SoilT_Well2_Shaded_180cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_180cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_180cm[:,:,:] = getData365(df_tsoilwell, 'SoilT_Well2_Shaded_180cm_degC', jdan=365)

#SoilT_Well2_Shaded_280cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_280cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_280cm[:,:,:] = getData365(df_tsoilwell, 'SoilT_Well2_Shaded_280cm_degC', jdan=365)

#SoilT_Well2_Shaded_380cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_380cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_380cm[:,:,:] = getData365(df_tsoilwell, 'SoilT_Well2_Shaded_380cm_degC', jdan=365)

#SoilT_Well2_Shaded_480cm = nc_tsoilwell.createVariable('SoilT_Well2_Shaded_480cm', np.float64, ('year','DOY','Hournumeric',))
SoilT_Well2_Shaded_480cm[:,:,:] = getData365(df_tsoilwell, 'SoilT_Well2_Shaded_480cm_degC', jdan=365)

## nc_vwwell

#annee_vwwell = nc_vwwell.createVariable('year', np.float64, ('year',))
annee_vwwell[:] = annee

#doy_vwwell = nc_vwwell.createVariable('doy', np.float64, ('DOY',))
doy_vwwell[:] = doy

#hnum_vwwell = nc_vwwell.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_vwwell[:] = hnum

#SoilVWC_Well2_Shaded_20cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_20cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_20cm[:,:,:] =  getData365(df_vwwell, 'SoilVWC_Well2_Shaded_20cm_m3H2Om3soil', jdan=365)

#SoilVWC_Well2_Shaded_40cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_40cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_40cm[:,:,:] =  getData365(df_vwwell, 'SoilVWC_Well2_Shaded_40cm_m3H2Om3soil', jdan=365)

#SoilVWC_Well2_Shaded_60cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_60cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_60cm[:,:,:] =  getData365(df_vwwell, 'SoilVWC_Well2_Shaded_60cm_m3H2Om3soil', jdan=365)

#SoilVWC_Well2_Shaded_80cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_80cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_80cm[:,:,:] =  getData365(df_vwwell, 'SoilVWC_Well2_Shaded_80cm_m3H2Om3soil', jdan=365)

#SoilVWC_Well2_Shaded_120cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_120cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_120cm[:,:,:] =  getData365(df_vwwell, 'SoilVWC_Well2_Shaded_120cm_m3H2Om3soil', jdan=365)

#SoilVWC_Well2_Shaded_140cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_140cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_140cm[:,:,:] =  getData365(df_vwwell, 'SoilVWC_Well2_Shaded_140cm_m3H2Om3soil', jdan=365)

#SoilVWC_Well2_Shaded_160cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_160cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_160cm[:,:,:] =  getData365(df_vwwell, 'SoilVWC_Well2_Shaded_160cm_m3H2Om3soil', jdan=365)

#SoilVWC_Well2_Shaded_180cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_180cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_180cm[:,:,:] =  getData365(df_vwwell, 'SoilVWC_Well2_Shaded_180cm_m3H2Om3soil', jdan=365)

#SoilVWC_Well2_Shaded_280cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_280cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_280cm[:,:,:] =  getData365(df_vwwell, 'SoilVWC_Well2_Shaded_280cm_m3H2Om3soil', jdan=365)

#SoilVWC_Well2_Shaded_380cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_380cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_380cm[:,:,:] =  getData365(df_vwwell, 'SoilVWC_Well2_Shaded_380cm_m3H2Om3soil', jdan=365)

#SoilVWC_Well2_Shaded_480cm = nc_vwwell.createVariable('SoilVWC_Well2_Shaded_480cm', np.float64, ('year','DOY','Hournumeric',))
SoilVWC_Well2_Shaded_480cm[:,:,:] =  getData365(df_vwwell, 'SoilVWC_Well2_Shaded_480cm_m3H2Om3soil', jdan=365)

# %% [markdown]
# ### meteo

# %%
# meteo
## nc_msSmallAnt 
#annee_msSmallAnt = nc_msSmallAnt.createVariable('year', np.float64, ('year',))
annee_msSmallAnt[:] = annee

#doy_msSmallAnt = nc_msSmallAnt.createVariable('doy', np.float64, ('DOY',))
doy_msSmallAnt[:] = doy

#hnum_msSmallAnt = nc_msSmallAnt.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_msSmallAnt[:] = hnum

#Tair_2m_SmallAnt = nc_msSmallAnt.createVariable('Tair_2m_SmallAnt', np.float64, ('year','DOY','Hournumeric',))
Tair_2m_SmallAnt[:,:,:] = getData365(df_msSmallAnt, 'Tair_2m_SmallAnt_degC', jdan=365)

#Rh_2m_SmallAnt = nc_msSmallAnt.createVariable('Delta2m_kPadegC', np.float64, ('year','DOY','Hournumeric',))
Rh_2m_SmallAnt[:,:,:] = getData365(df_msSmallAnt, 'Rh_2m_SmallAnt_pc', jdan=365)

#WS_2m_SmallAntSonic_ms = nc_msSmallAnt.createVariable('WS_2m_SmallAntSonic_ms', np.float64, ('year','DOY','Hournumeric',))
WS_2m_SmallAntSonic_ms[:,:,:] = getData365(df_msSmallAnt, 'WS_2m_SmallAntSonic_ms', jdan=365)

#VPD_2m_hPa = nc_msSmallAnt.createVariable('VPD_2m_hPa', np.float64, ('year','DOY','Hournumeric',))
VPD_2m_hPa[:,:,:] = getData365(df_msSmallAnt, 'VPD_2m_hPa.Gf', jdan=365)

#ETo_2m_mmsemih_Gf = nc_msSmallAnt.createVariable('ETo_2m_mmsemih_Gf', np.float64, ('year','DOY','Hournumeric',))
ETo_2m_mmsemih_Gf[:,:,:] = getData365(df_msSmallAnt, 'ETo_2m_mmsemih_Gf', jdan=365)

## nc_msTallAnt
#annee_msTallAnt = nc_msTallAnt.createVariable('year', np.float64, ('year',))
annee_msTallAnt[:] = annee

#doy_msTallAnt = nc_msTallAnt.createVariable('doy', np.float64, ('DOY',))
doy_msTallAnt[:] = doy

#hnum_msTallAnt = nc_msTallAnt.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_msTallAnt[:] = hnum
            
#PARtot_20m_mE = nc_msTallAnt.createVariable('PARtot_20m_mE', np.float64, ('year','DOY','Hournumeric',))
PARtot_20m_mE[:,:,:] = getData365(df_msTallAnt, 'PARtot_20m_mE', jdan=365)

#NDVI_TallAnt_crop = nc_msTallAnt.createVariable('NDVI_TallAnt_crop', np.float64, ('year','DOY','Hournumeric',))
NDVI_TallAnt_crop[:,:,:] = getData365(df_msTallAnt, 'NDVI_TallAnt_crop', jdan=365)

#Tair_20m_degC = nc_msTallAnt.createVariable('Tair_20m_degC', np.float64, ('year','DOY','Hournumeric',))
Tair_20m_degC[:,:,:] = getData365(df_msTallAnt, 'Tair_20m_degC', jdan=365)

#Rh_20m_pc = nc_msTallAnt.createVariable('Rh_20m_pc', np.float64, ('year','DOY','Hournumeric',))
Rh_20m_pc[:,:,:] = getData365(df_msTallAnt, 'Rh_20m_pc', jdan=365)

#WindSpeed_20m_ms1 = nc_msTallAnt.createVariable('WindSpeed_20m_ms1', np.float64, ('year','DOY','Hournumeric',))
WindSpeed_20m_ms1[:,:,:] = getData365(df_msTallAnt, 'WindSpeed_20m_ms1', jdan=365)

#WindDir_20m_deg = nc_msTallAnt.createVariable('WindDir_20m_deg', np.float64, ('year','DOY','Hournumeric',))
WindDir_20m_deg[:,:,:] = getData365(df_msTallAnt, 'WindDir_20m_deg', jdan=365)

#Rain_mmsemih = nc_msTallAnt.createVariable('Rain_mmsemih', np.float64, ('year','DOY','Hournumeric',))
Rain_mmsemih[:,:,:] = getData365(df_msTallAnt, 'Rain_mmsemih', jdan=365)

#P_20m_hPa = nc_msTallAnt.createVariable('P_20m_hPa', np.float64, ('year','DOY','Hournumeric',))
P_20m_hPa[:,:,:] = getData365(df_msTallAnt, 'P_20m_hPa', jdan=365)

#eVais_20m_hPa = nc_msTallAnt.createVariable('eVais_20m_hPa', np.float64, ('year','DOY','Hournumeric',))
eVais_20m_hPa[:,:,:] = getData365(df_msTallAnt, 'eVais_20m_hPa', jdan=365)

#VPD_20m_hPa = nc_msTallAnt.createVariable('VPD_20m_hPa', np.float64, ('year','DOY','Hournumeric',))
VPD_20m_hPa[:,:,:] = getData365(df_msTallAnt, 'VPD_20m_hPa', jdan=365)

#PARtot_20m_mE_filt = nc_msTallAnt.createVariable('PARtot_20m_mE_filt', np.float64, ('year','DOY','Hournumeric',))
PARtot_20m_mE_filt[:,:,:] = getData365(df_msTallAnt, 'PARtot_20m_mE_filt', jdan=365)

#Rg_estim_20m = nc_msTallAnt.createVariable('Rg_estim_20m', np.float64, ('year','DOY','Hournumeric',))
Rg_estim_20m[:,:,:] = getData365(df_msTallAnt, 'Rg_estim_20m.Gf', jdan=365)

#PARDiff_ModEmpir = nc_msTallAnt.createVariable('PARDiff_ModEmpir', np.float64, ('year','DOY','Hournumeric',))
PARDiff_ModEmpir[:,:,:] = getData365(df_msTallAnt, 'PARDiff.ModEmpir.Gf', jdan=365)

#Diff_Fraction_ModEmpir = nc_msTallAnt.createVariable('Diff_Fraction_ModEmpir', np.float64, ('year','DOY','Hournumeric',))
Diff_Fraction_ModEmpir[:,:,:] = getData365(df_msTallAnt, 'Diff.Fraction.ModEmpir.Gf', jdan=365)

#IR100_LST_TallAnt_degC = nc_msTallAnt.createVariable('IR100_LST_TallAnt_degC', np.float64, ('year','DOY','Hournumeric',))
IR100_LST_TallAnt_degC[:,:,:] = getData365(df_msTallAnt, 'IR100_LST_TallAnt_degC', jdan=365)

#IR120_LST_TallAnt_degC = nc_msTallAnt.createVariable('IR120_LST_TallAnt_degC', np.float64, ('year','DOY','Hournumeric',))
IR120_LST_TallAnt_degC[:,:,:] = getData365(df_msTallAnt, 'IR120_LST_TallAnt_degC', jdan=365)

#ETo_20m_mmh_Gf = nc_msTallAnt.createVariable('ETo_20m_mmh_Gf', np.float64, ('year','DOY','Hournumeric',))
ETo_20m_mmh_Gf[:,:,:] = getData365(df_msTallAnt, 'ETo_20m_mmh_Gf', jdan=365)

###
#annee_fluxTallAnt = nc_fluxTallAnt.createVariable('year', np.float64, ('year',))
annee_fluxTallAnt[:] = annee

#doy_fluxTallAnt = nc_fluxTallAnt.createVariable('doy', np.float64, ('DOY',))
doy_fluxTallAnt[:] = doy

#hnum_fluxTallAnt = nc_fluxTallAnt.createVariable('Hournumeric', np.float64, ('Hournumeric',))
hnum_fluxTallAnt[:] = hnum

#NEE_micmolm2s_20m = nc_fluxTallAnt.createVariable('NEE_micmolm2s_20m', np.float64, ('year','DOY','Hournumeric',))
NEE_micmolm2s_20m[:,:,:] = getData365(df_fluxTallAnt, 'NEE_micmolm2s_20m', jdan=365)

#LE_Wm2__20m = nc_fluxTallAnt.createVariable('LE_Wm2__20m', np.float64, ('year','DOY','Hournumeric',))
LE_Wm2__20m[:,:,:] = getData365(df_fluxTallAnt, 'LE_Wm2__20m', jdan=365)

#H_Wm2_20m = nc_fluxTallAnt.createVariable('H_Wm2_20m', np.float64, ('year','DOY','Hournumeric',))
H_Wm2_20m[:,:,:] = getData365(df_fluxTallAnt, 'H_Wm2_20m', jdan=365)

#Ustar_Thres_20m = nc_fluxTallAnt.createVariable('Ustar_Thres_20m', np.float64, ('year','DOY','Hournumeric',))
Ustar_Thres_20m[:,:,:] = getData365(df_fluxTallAnt, 'Ustar_Thres_20m', jdan=365)

#Reco_MR_micmolm2s_20m = nc_fluxTallAnt.createVariable('Reco_MR_micmolm2s_20m', np.float64, ('year','DOY','Hournumeric',))
Reco_MR_micmolm2s_20m[:,:,:] = getData365(df_fluxTallAnt, 'Reco_MR_micmolm2s_20m', jdan=365)

#GPP_MR_micmolm2s_20m = nc_fluxTallAnt.createVariable('GPP_MR_micmolm2s_20m', np.float64, ('year','DOY','Hournumeric',))
GPP_MR_micmolm2s_20m[:,:,:] = getData365(df_fluxTallAnt, 'GPP_MR_micmolm2s_20m', jdan=365)

#GPP_MR_Gfqc_20m = nc_fluxTallAnt.createVariable('GPP_MR_Gfqc_20m', np.float64, ('year','DOY','Hournumeric',))
GPP_MR_Gfqc_20m[:,:,:] = getData365(df_fluxTallAnt, 'GPP_MR_Gfqc_20m', jdan=365)

#Reco_DT_micmolm2s_20m = nc_fluxTallAnt.createVariable('Reco_DT_micmolm2s_20m', np.float64, ('year','DOY','Hournumeric',))
Reco_DT_micmolm2s_20m[:,:,:] = getData365(df_fluxTallAnt, 'Reco_DT_micmolm2s_20m', jdan=365)

#GPP_DT_micmolm2s_20m = nc_fluxTallAnt.createVariable('GPP_DT_micmolm2s_20m', np.float64, ('year','DOY','Hournumeric',))
GPP_DT_micmolm2s_20m[:,:,:] = getData365(df_fluxTallAnt, 'GPP_DT_micmolm2s_20m', jdan=365)

#GPP_DT_uStar_SD_micmolm2s_20m = nc_fluxTallAnt.createVariable('GPP_DT_uStar_SD_micmolm2s_20m', np.float64, ('year','DOY','Hournumeric',))
GPP_DT_uStar_SD_micmolm2s_20m[:,:,:] = getData365(df_fluxTallAnt, 'GPP_DT_uStar_SD_micmolm2s_20m', jdan=365)

#LE_Gf_Wm2_20m = nc_fluxTallAnt.createVariable('LE_Gf_Wm2_20m', np.float64, ('year','DOY','Hournumeric',))
LE_Gf_Wm2_20m[:,:,:] = getData365(df_fluxTallAnt, 'LE_Gf_Wm2_20m', jdan=365)

#LE_Gfqc_20m = nc_fluxTallAnt.createVariable('LE_Gfqc_20m', np.float64, ('year','DOY','Hournumeric',))
LE_Gfqc_20m[:,:,:] = getData365(df_fluxTallAnt, 'LE_Gfqc_20m', jdan=365)

#H_Gf_20m = nc_fluxTallAnt.createVariable('H_Gf_20m', np.float64, ('year','DOY','Hournumeric',))
H_Gf_20m[:,:,:] = getData365(df_fluxTallAnt, 'H_Gf_20m', jdan=365)

#H_Gfqc_20m = nc_fluxTallAnt.createVariable('H_Gfqc_20m', np.float64, ('year','DOY','Hournumeric',))
H_Gfqc_20m[:,:,:] = getData365(df_fluxTallAnt, 'H_Gfqc_20m', jdan=365)

# %% [markdown]
# ### fermeture des fichiers netcdf

# %%
#meteo soil
nc_tsoilfs.close()
nc_vwfs.close()
nc_tsoilwell.close()
nc_vwwell.close()

#tree
nc_leafRate.close()
nc_leafAD.close()
nc_leafAPT.close()
nc_dripLLAI.close()
nc_CWNDVI.close()
nc_LaicwAntPlotScale.close()
nc_LaiTreecwAntPlotScale.close()
nc_woodW.close()
nc_netRadiation.close()

# meteo
nc_msSmallAnt.close()
nc_msTallAnt.close()
nc_fluxTallAnt.close()
print('Dataset is closed!')
# Out:
# Dataset is closed!
